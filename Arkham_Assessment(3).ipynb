# %% [markdown]
# ### Import necessary library

# %%
import time
import requests
import hashlib
import base64
import hmac
import json
from pprint import pprint
from pyspark.sql.functions import *
from pyspark.sql.types import *
from pyspark.sql import SparkSession
from pyspark.sql.functions import lit
from functools import reduce
from pyspark.sql import DataFrame

# %% [markdown]
# # Declaring API Key and params

# %%
ARKHAM_API_KEY = "f87e20f4-2053-4afc-8dd2-39c32fb5c7a8"

# %% [markdown]
# # Setting up functions to call whenever needed

# %%
class ArkhamAPI:
    BASE_URL = "https://arkm.com/api"

    def __init__(self, api_key):
        self.api_key = api_key

    def get_assets(self, chain=None):
        url = f"{self.BASE_URL}/public/assets"
        headers = {
            "API-Key": self.api_key,
            "Accept": "application/json"
        }

        params = {}
        if chain:
            params["chain"] = chain

        response = requests.get(url, headers=headers, params=params, timeout=10)
        print(f"HTTP Status: {response.status_code}")
        if response.status_code != 200:
            print("Error response:", response.json())
            return None

        return response.json()

    def get_contracts(self, chain=None):
        url = f"{self.BASE_URL}/public/contracts"
        headers = {
            "API-Key": self.api_key,
            "Accept": "application/json"
        }

        params = {}
        if chain:
            params["chain"] = chain

        response = requests.get(url, headers=headers, params=params, timeout=10)
        print(f"HTTP Status: {response.status_code}")
        if response.status_code != 200:
            print("Error response:", response.json())
            return None

        return response.json()

    def get_solana_assets(self):
        assets = self.get_assets(chain="solana")
        if not assets:
            print("No assets returned for Solana or error occurred.")
            return []

        sol_assets = [
            asset for asset in assets
            if any(chain_info.get("symbol") == "SOL" or chain_info.get("name", "").lower() == "solana"
                   for chain_info in asset.get("chains", []))
        ]
        return sol_assets

    def get_all_contracts(self):
        contracts = self.get_contracts()
        if not contracts:
            print("No contracts returned or error occurred.")
            return []
        return contracts

# %%
# =====================
# Usage
# =====================
if __name__ == "__main__":
    api = ArkhamAPI(ARKHAM_API_KEY)
    solana_assets = api.get_solana_assets()
    print(solana_assets)
# Out:
# HTTP Status: 200
# [{'symbol': 'SOL', 'name': 'Solana', 'geckoId': 'solana', 'imageUrl': 'https://static.arkhamintelligence.com/tokens/solana.png', 'stablecoin': False, 'featuredPair': 'SOL_USDT', 'chains': [{'symbol': 'SOL', 'assetSymbol': 'SOL', 'name': 'Solana', 'type': 4, 'confirmations': 32, 'blockTime': 400000}], 'status': 'listed', 'minDeposit': '0.05', 'minWithdrawal': '0.05', 'withdrawalFee': '0.02'}, {'symbol': 'WIF', 'name': 'Dogwifhat', 'geckoId': 'dogwifcoin', 'imageUrl': 'https://static.arkhamintelligence.com/tokens/dogwifhat-eth.png', 'stablecoin': False, 'featuredPair': 'WIF_USDT', 'chains': [{'symbol': 'SOL', 'assetSymbol': 'SOL', 'name': 'Solana', 'type': 4, 'confirmations': 32, 'blockTime': 400000}], 'status': 'listed', 'minDeposit': '4', 'minWithdrawal': '4', 'withdrawalFee': '1.5'}, {'symbol': 'BONK', 'name': 'Bonk', 'geckoId': 'bonk', 'imageUrl': 'https://static.arkhamintelligence.com/tokens/bonk.png', 'stablecoin': False, 'featuredPair': 'BONK_USDT', 'chains': [{'symbol': 'SOL', 'assetSymbol': 'SOL', 'name': 'Solana', 'type': 4, 'confirmations': 32, 'blockTime': 400000}], 'status': 'listed', 'minDeposit': '200000', 'minWithdrawal': '200000', 'withdrawalFee': '100000'}, {'symbol': 'RENDER', 'name': 'Render', 'geckoId': 'render', 'imageUrl': 'https://static.arkhamintelligence.com/tokens/render-token.png', 'stablecoin': False, 'featuredPair': 'RENDER_USDT', 'chains': [{'symbol': 'SOL', 'assetSymbol': 'SOL', 'name': 'Solana', 'type': 4, 'confirmations': 32, 'blockTime': 400000}], 'status': 'listed', 'minDeposit': '1', 'minWithdrawal': '1', 'withdrawalFee': '0.5'}, {'symbol': 'TRUMP', 'name': 'OFFICIAL TRUMP', 'geckoId': 'official-trump', 'imageUrl': 'https://static.arkhamintelligence.com/tokens/official-trump.png', 'stablecoin': False, 'featuredPair': 'TRUMP_USDT', 'chains': [{'symbol': 'SOL', 'assetSymbol': 'SOL', 'name': 'Solana', 'type': 4, 'confirmations': 32, 'blockTime': 400000}], 'status': 'listed', 'minDeposit': '0.4', 'minWithdrawal': '0.4', 'withdrawalFee': '0.1'}, {'symbol': 'MELANIA', 'name': 'Melania Meme', 'geckoId': 'melania-meme', 'imageUrl': 'https://static.arkhamintelligence.com/tokens/melania-meme.png', 'stablecoin': False, 'featuredPair': 'MELANIA_USDT', 'chains': [{'symbol': 'SOL', 'assetSymbol': 'SOL', 'name': 'Solana', 'type': 4, 'confirmations': 32, 'blockTime': 400000}], 'status': 'listed', 'minDeposit': '5', 'minWithdrawal': '5', 'withdrawalFee': '2'}, {'symbol': 'JUP', 'name': 'Jupiter', 'geckoId': 'jupiter-exchange-solana', 'imageUrl': 'https://static.arkhamintelligence.com/tokens/jupiter-exchange-solana.png', 'stablecoin': False, 'featuredPair': 'JUP_USDT', 'chains': [{'symbol': 'SOL', 'assetSymbol': 'SOL', 'name': 'Solana', 'type': 4, 'confirmations': 32, 'blockTime': 400000}], 'status': 'listed', 'minDeposit': '5', 'minWithdrawal': '5', 'withdrawalFee': '3'}, {'symbol': 'PYTH', 'name': 'Pyth Network', 'geckoId': 'pyth-network', 'imageUrl': 'https://static.arkhamintelligence.com/tokens/pyth-network.png', 'stablecoin': False, 'featuredPair': 'PYTH_USDT', 'chains': [{'symbol': 'SOL', 'assetSymbol': 'SOL', 'name': 'Solana', 'type': 4, 'confirmations': 32, 'blockTime': 400000}], 'status': 'listed', 'minDeposit': '30', 'minWithdrawal': '30', 'withdrawalFee': '10'}, {'symbol': 'POPCAT', 'name': 'Popcat', 'geckoId': 'popcat', 'imageUrl': 'https://static.arkhamintelligence.com/tokens/popcat.png', 'stablecoin': False, 'featuredPair': 'POPCAT_USDT', 'chains': [{'symbol': 'SOL', 'assetSymbol': 'SOL', 'name': 'Solana', 'type': 4, 'confirmations': 32, 'blockTime': 400000}], 'status': 'listed', 'minDeposit': '17.5', 'minWithdrawal': '17.5', 'withdrawalFee': '7'}, {'symbol': 'GRASS', 'name': 'Grass', 'geckoId': 'grass', 'imageUrl': 'https://static.arkhamintelligence.com/tokens/grass.png', 'stablecoin': False, 'featuredPair': 'GRASS_USDT', 'chains': [{'symbol': 'SOL', 'assetSymbol': 'SOL', 'name': 'Solana', 'type': 4, 'confirmations': 32, 'blockTime': 400000}], 'status': 'listed', 'minDeposit': '3.38', 'minWithdr ...

# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import explode, col

# =====================
# Initialize Spark
# =====================
spark = SparkSession.builder \
    .appName("SolanaAssetsAnalysis") \
    .getOrCreate()

df = spark.createDataFrame(solana_assets)

df.createOrReplaceTempView("solana_tokens")

print("These are some of the available token that is available for analysis in Solana chain")
spark.sql("SELECT DISTINCT name, symbol FROM solana_tokens").show(truncate=False)
# Out:
# These are some of the available token that is available for analysis in Solana chain
# +--------------+--------+
# |name          |symbol  |
# +--------------+--------+
# |Render        |RENDER  |
# |Jupiter       |JUP     |
# |Dogwifhat     |WIF     |
# |Bonk          |BONK    |
# |OFFICIAL TRUMP|TRUMP   |
# |Melania Meme  |MELANIA |
# |Solana        |SOL     |
# |Pudgy Penguins|PENGU   |
# |Grass         |GRASS   |
# |Jito          |JTO     |
# |Pump.fun      |PUMP    |
# |Popcat        |POPCAT  |
# |Fartcoin      |FARTCOIN|
# |Pyth Network  |PYTH    |
# +--------------+--------+

# %%
spark.sql("""
SELECT *
FROM solana_tokens
""").show(truncate=False)
# Out:
# +----------------------------------------------------------------------------------------------------------+-------------+-----------------------+------------------------------------------------------------------------+----------+-------------+--------------+----------+------+--------+-------------+
# |chains                                                                                                    |featuredPair |geckoId                |imageUrl                                                                |minDeposit|minWithdrawal|name          |stablecoin|status|symbol  |withdrawalFee|
# +----------------------------------------------------------------------------------------------------------+-------------+-----------------------+------------------------------------------------------------------------+----------+-------------+--------------+----------+------+--------+-------------+
# |[{symbol -> SOL, assetSymbol -> SOL, name -> Solana, blockTime -> 400000, confirmations -> 32, type -> 4}]|SOL_USDT     |solana                 |https://static.arkhamintelligence.com/tokens/solana.png                 |0.05      |0.05         |Solana        |false     |listed|SOL     |0.02         |
# |[{symbol -> SOL, assetSymbol -> SOL, name -> Solana, blockTime -> 400000, confirmations -> 32, type -> 4}]|WIF_USDT     |dogwifcoin             |https://static.arkhamintelligence.com/tokens/dogwifhat-eth.png          |4         |4            |Dogwifhat     |false     |listed|WIF     |1.5          |
# |[{symbol -> SOL, assetSymbol -> SOL, name -> Solana, blockTime -> 400000, confirmations -> 32, type -> 4}]|BONK_USDT    |bonk                   |https://static.arkhamintelligence.com/tokens/bonk.png                   |200000    |200000       |Bonk          |false     |listed|BONK    |100000       |
# |[{symbol -> SOL, assetSymbol -> SOL, name -> Solana, blockTime -> 400000, confirmations -> 32, type -> 4}]|RENDER_USDT  |render                 |https://static.arkhamintelligence.com/tokens/render-token.png           |1         |1            |Render        |false     |listed|RENDER  |0.5          |
# |[{symbol -> SOL, assetSymbol -> SOL, name -> Solana, blockTime -> 400000, confirmations -> 32, type -> 4}]|TRUMP_USDT   |official-trump         |https://static.arkhamintelligence.com/tokens/official-trump.png         |0.4       |0.4          |OFFICIAL TRUMP|false     |listed|TRUMP   |0.1          |
# |[{symbol -> SOL, assetSymbol -> SOL, name -> Solana, blockTime -> 400000, confirmations -> 32, type -> 4}]|MELANIA_USDT |melania-meme           |https://static.arkhamintelligence.com/tokens/melania-meme.png           |5         |5            |Melania Meme  |false     |listed|MELANIA |2            |
# |[{symbol -> SOL, assetSymbol -> SOL, name -> Solana, blockTime -> 400000, confirmations -> 32, type -> 4}]|JUP_USDT     |jupiter-exchange-solana|https://static.arkhamintelligence.com/tokens/jupiter-exchange-solana.png|5         |5            |Jupiter       |false     |listed|JUP     |3            |
# |[{symbol -> SOL, assetSymbol -> SOL, name -> Solana, blockTime -> 400000, confirmations -> 32, type -> 4}]|PYTH_USDT    |pyth-network           |https://static.arkhamintelligence.com/tokens/pyth-network.png           |30        |30           |Pyth Network  |false     |listed|PYTH    |10           |
# |[{symbol -> SOL, assetSymbol -> SOL, name -> Solana, blockTime -> 400000, confirmations -> 32, type -> 4}]|POPCAT_USDT  |popcat                 |https://static.arkhamintelligence.com/tokens/popcat.png                 |17.5      |17.5         |Popcat        |false     |listed|POPCAT  |7            |
# |[{symbol -> SOL, assetSymbol -> SOL, name -> Solana, blockTime -> 400000, confirmations -> 32, type -> 4}]|GRASS_USDT   |grass                  |https://static.arkhamintelligence.com/tokens/grass.png                  |3.38      |3.38         |Grass         |false     |listed|GRASS   |1.35         |
# |[{symbol -> SOL, assetSymbol -> SOL, name -> Solana, blockTime -> 400000, confirmations -> 32, type -> 4}]|FARTCOIN_USDT|fartcoin               |https://static.arkhamintelligence.com/tokens/fartcoin.png               |4.39      |4.39         |Fartcoin      |false     |listed|FARTCOIN|1.75         |
# |[{symbol -> SOL, assetSymbol -> SOL, name -> Solana, blockTime -> 400000, confirmations -> 32, type -> 4}]|JTO_USDT     |jito-governance-token  |https://static.arkhamintelligence.com/tokens/jito-governance-token.png  |2.19      |2.19         |Jito          |false     |listed|JTO     |0.88         |
# |[{symbol -> SOL, assetSymbol -> SOL, name -> Solana, blockTime -> 400000, confirmations -> 32, type -> 4}]|PUMP_USDT    |pump-fun               |https://static.arkhamintelligence.com/tokens/pump-fun.png               |1250      |1250         |Pump.fun      |false     |listed|PUMP    |500          |
# |[{symbol -> SOL, assetSymbol -> SOL, name -> Solana, blockTime -> 400000, confirmations -> 32, type -> 4}]|PENGU_USDT   |pudgy-penguins         |https://static.arkhamintelligence.com/tokens/pudgy-penguins.png         |145       |145          |Pudgy Penguins|false     |listed|PENGU   |60           |
# +----------------------------------------------------------------------------------------------------------+-------------+-----------------------+------------------------------------------------------------------------+----------+-------------+--------------+----------+------+--------+-------------+

# %% [markdown]
# Doesn't show any interesting data that could contribute for risk score analysis

# %%
# =====================
# Usage
# =====================
if __name__ == "__main__":
    api = ArkhamAPI(ARKHAM_API_KEY)
    contracts = api.get_contracts()
    print(contracts)
# Out:
# HTTP Status: 200
# [{'symbol': 'BTC_USDT_PERP', 'baseSymbol': 'BTC.P', 'quoteSymbol': 'USDT', 'price': '84685.88', 'price24hAgo': '85744.04', 'high24h': '85766.02', 'low24h': '80621', 'volume24h': '37.41301', 'quoteVolume24h': '3147191.0233199', 'markPrice': '84749.61', 'indexPrice': '84762.921682027', 'fundingRate': '-0.000003', 'nextFundingRate': '-0.000003', 'nextFundingTime': 1763794800000000, 'productType': 'perpetual', 'openInterest': '2.86344', 'indexCurrency': 'USDT', 'usdVolume24h': '3147191.0233199', 'openInterestUSD': '242492.9362272'}, {'symbol': 'ETH_USDT_PERP', 'baseSymbol': 'ETH.P', 'quoteSymbol': 'USDT', 'price': '2766.34', 'price24hAgo': '2795.41', 'high24h': '2802.09', 'low24h': '2623.45', 'volume24h': '608.8565', 'quoteVolume24h': '1661478.641528', 'markPrice': '2765.66', 'indexPrice': '2766.158417438', 'fundingRate': '-0.000005', 'nextFundingRate': '-0.000005', 'nextFundingTime': 1763794800000000, 'productType': 'perpetual', 'openInterest': '75.68255', 'indexCurrency': 'USDT', 'usdVolume24h': '1661478.641528', 'openInterestUSD': '209363.665367'}, {'symbol': 'SOL_USDT_PERP', 'baseSymbol': 'SOL.P', 'quoteSymbol': 'USDT', 'price': '127.47', 'price24hAgo': '131.16', 'high24h': '131.16', 'low24h': '121.66', 'volume24h': '2345.428', 'quoteVolume24h': '296850.46225', 'markPrice': '127.93', 'indexPrice': '127.994904871', 'fundingRate': '-0.000019', 'nextFundingRate': '-0.000017', 'nextFundingTime': 1763794800000000, 'productType': 'perpetual', 'openInterest': '1157.744024824', 'indexCurrency': 'USDT', 'usdVolume24h': '296850.46225', 'openInterestUSD': '147577.630844315'}, {'symbol': 'ARKM_USDT_PERP', 'baseSymbol': 'ARKM.P', 'quoteSymbol': 'USDT', 'price': '0.2398', 'price24hAgo': '0.2587', 'high24h': '0.2603', 'low24h': '0.2282', 'volume24h': '409485.8', 'quoteVolume24h': '99684.04871', 'markPrice': '0.2394', 'indexPrice': '0.239234218', 'fundingRate': '0.00002', 'nextFundingRate': '0.000006', 'nextFundingTime': 1763794800000000, 'productType': 'perpetual', 'openInterest': '17868.5', 'indexCurrency': 'USDT', 'usdVolume24h': '99684.04871', 'openInterestUSD': '4284.8663'}, {'symbol': 'DOGE_USDT_PERP', 'baseSymbol': 'DOGE.P', 'quoteSymbol': 'USDT', 'price': '0.138', 'price24hAgo': '0.14542', 'high24h': '0.14655', 'low24h': '0.13334', 'volume24h': '190630', 'quoteVolume24h': '26247.842', 'markPrice': '0.13931', 'indexPrice': '0.139355876', 'fundingRate': '-0.000005', 'nextFundingRate': '-0.000006', 'nextFundingTime': 1763794800000000, 'productType': 'perpetual', 'openInterest': '151020', 'indexCurrency': 'USDT', 'usdVolume24h': '26247.842', 'openInterestUSD': '20840.76'}, {'symbol': 'PEPE_USDT_PERP', 'baseSymbol': 'PEPE.P', 'quoteSymbol': 'USDT', 'price': '0.00000406', 'price24hAgo': '0.00000446', 'high24h': '0.00000449', 'low24h': '0.00000395', 'volume24h': '2199358803', 'quoteVolume24h': '9240.61255073', 'markPrice': '0.00000408', 'indexPrice': '0.000004081', 'fundingRate': '0.000009', 'nextFundingRate': '-0.000005', 'nextFundingTime': 1763794800000000, 'productType': 'perpetual', 'openInterest': '7692005006', 'indexCurrency': 'USDT', 'usdVolume24h': '9240.61255073', 'openInterestUSD': '31229.54032436'}, {'symbol': 'WIF_USDT_PERP', 'baseSymbol': 'WIF.P', 'quoteSymbol': 'USDT', 'price': '0.3182', 'price24hAgo': '0.3749', 'high24h': '0.3756', 'low24h': '0.3107', 'volume24h': '87438.91', 'quoteVolume24h': '30165.106897', 'markPrice': '0.3193', 'indexPrice': '0.319297926', 'fundingRate': '-0.000003', 'nextFundingRate': '0.000003', 'nextFundingTime': 1763794800000000, 'productType': 'perpetual', 'openInterest': '53959.875', 'indexCurrency': 'USDT', 'usdVolume24h': '30165.106897', 'openInterestUSD': '17170.032225'}, {'symbol': 'TON_USDT_PERP', 'baseSymbol': 'TON.P', 'quoteSymbol': 'USDT', 'price': '1.497', 'price24hAgo': '1.547', 'high24h': '1.553', 'low24h': '1.451', 'volume24h': '37154.79', 'quoteVolume24h': '55761.33817', 'markPrice': '1.499', 'indexPrice': '1.500161862', 'fundingRate': '-0.000024', 'nextFundingRate': '-0.000022', 'nextFu ...

# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import explode, col

# Create DataFrame for contracts
df_contracts = spark.createDataFrame(contracts)
df_contracts.createOrReplaceTempView("contracts")

# Create DataFrame for solana_assets and get distinct symbols
df_solana_assets = spark.createDataFrame(solana_assets)
df_distinct_solana_symbols = df_solana_assets.select("symbol").distinct()
df_distinct_solana_symbols.createOrReplaceTempView("solana_tokens_distinct")


# Let us pick 5 tokens to make a risk score metrics
df_solana_contracts = spark.sql("""
SELECT
    c.*,
    from_unixtime(nextFundingTime / 1000000) AS nextFundingTimestamp_transformed
FROM contracts c
JOIN solana_tokens_distinct s
  ON c.baseSymbol LIKE CONCAT(s.symbol, '%')
  order by baseSymbol
  limit 5;
""")

df_solana_contracts.createOrReplaceTempView("solana_contracts_view")

df_solana_contracts.show(truncate=False)
# Out:
# +----------+-----------+----------+-------------+-----------+----------+----------+---------------+----------------+------------+---------------+----------+-----------+-----------+-----------+--------------+------------------+--------------+----------+--------------------------------+
# |baseSymbol|fundingRate|high24h   |indexCurrency|indexPrice |low24h    |markPrice |nextFundingRate|nextFundingTime |openInterest|openInterestUSD|price     |price24hAgo|productType|quoteSymbol|quoteVolume24h|symbol            |usdVolume24h  |volume24h |nextFundingTimestamp_transformed|
# +----------+-----------+----------+-------------+-----------+----------+----------+---------------+----------------+------------+---------------+----------+-----------+-----------+-----------+--------------+------------------+--------------+----------+--------------------------------+
# |BONK.P    |-0.000011  |0.00000959|USDT         |0.000008678|0.00000846|0.00000867|-0.000014      |1763794800000000|204656973   |1768.23624672  |0.00000864|0.00000954 |perpetual  |USDT       |36407.83796539|BONK_USDT_PERP    |36407.83796539|4072703476|2025-11-22 07:00:00             |
# |FARTCOIN.P|0.000006   |0.2496    |USDT         |0.210017672|0.2034    |0.21      |0.000005       |1763794800000000|0.4         |0.08404        |0.2101    |0.2485     |perpetual  |USDT       |347.18889     |FARTCOIN_USDT_PERP|347.18889     |1526.9    |2025-11-22 07:00:00             |
# |GRASS.P   |0.000001   |0.5026    |USDT         |0.342169098|0.3245    |0.3417    |0.000003       |1763794800000000|5.8         |1.95518        |0.3371    |0.4851     |perpetual  |USDT       |202.97898     |GRASS_USDT_PERP   |202.97898     |524.6     |2025-11-22 07:00:00             |
# |JTO.P     |-0.000008  |0.5109    |USDT         |0.46501125 |0.4519    |0.4651    |-0.000002      |1763794800000000|2012.4      |934.96104      |0.4646    |0.5092     |perpetual  |USDT       |292.30815     |JTO_USDT_PERP     |292.30815     |609.1     |2025-11-22 07:00:00             |
# |JUP.P     |-0.000002  |0.2515    |USDT         |0.239055924|0.2277    |0.239     |-0.000003      |1763794800000000|83683       |20016.9736     |0.2392    |0.2502     |perpetual  |USDT       |6889.55584    |JUP_USDT_PERP     |6889.55584    |28521.8   |2025-11-22 07:00:00             |
# +----------+-----------+----------+-------------+-----------+----------+----------+---------------+----------------+------------+---------------+----------+-----------+-----------+-----------+--------------+------------------+--------------+----------+--------------------------------+

# %% [markdown]
# #  Risk Score

# %%
spark.sql("""

WITH stats AS (
    -- Compute min/max values for normalization
    SELECT
        MIN(openInterestUSD / NULLIF(usdVolume24h, 0)) AS min_ratio,
        MAX(openInterestUSD / NULLIF(usdVolume24h, 0)) AS max_ratio,
        MIN(ABS(nextFundingRate)) AS min_funding,
        MAX(ABS(nextFundingRate)) AS max_funding,
        MIN(ABS(price - markPrice)/NULLIF(markPrice,0)) AS min_price_gap,
        MAX(ABS(price - markPrice)/NULLIF(markPrice,0)) AS max_price_gap
    FROM solana_contracts_view
),
token_risks AS (
    SELECT
        c.baseSymbol,
        c.openInterestUSD,
        c.usdVolume24h,
        c.nextFundingRate AS fundingRate,
        c.price,
        c.markPrice,
        s.min_ratio,
        s.max_ratio,
        s.min_funding,
        s.max_funding,
        s.min_price_gap,
        s.max_price_gap,

        -- Liquidity risk: smaller OI → higher risk, clamped 0–1
        ROUND(
            1 - CASE
                WHEN c.usdVolume24h > 0 THEN
                    ( (c.openInterestUSD / c.usdVolume24h) - min_ratio )
                    / NULLIF((max_ratio - min_ratio), 0)
                ELSE
                    1  -- no volume = extremely illiquid = highest risk
            END,
        3
        ) AS liquidity_risk,

        -- Funding risk: scaled 0–1
        GREATEST(0, LEAST(1,
            CASE WHEN s.max_funding > s.min_funding THEN
                (ABS(c.nextFundingRate) - s.min_funding) / (s.max_funding - s.min_funding)
            ELSE 0 END
        )) AS funding_risk,

        -- Price gap risk: scaled 0–1
        GREATEST(0, LEAST(1,
            CASE WHEN s.max_price_gap > s.min_price_gap THEN
                (ABS(c.price - c.markPrice)/NULLIF(c.markPrice,0) - s.min_price_gap) / (s.max_price_gap - s.min_price_gap)
            ELSE 0 END
        )) AS price_gap_risk
    FROM solana_contracts_view c
    CROSS JOIN stats s
)

SELECT
    baseSymbol,
    openInterestUSD,
    usdVolume24h,
    fundingRate,
    price,
    markPrice,
    ROUND(liquidity_risk * 100, 2) AS liquidity_risk,
    ROUND(funding_risk * 100, 2) AS funding_risk,
    ROUND(price_gap_risk * 100, 2) AS price_gap_risk,

    -- Composite risk: average of three components, scaled 0–100
    ROUND((liquidity_risk + funding_risk + price_gap_risk)/3 * 100, 2) AS composite_risk_score,

    -- Risk tier classification
    CASE
        WHEN ROUND((liquidity_risk + funding_risk + price_gap_risk)/3 * 100, 2)  > 70 THEN 'HIGH RISK'
        WHEN ROUND((liquidity_risk + funding_risk + price_gap_risk)/3 * 100, 2)  > 50 THEN 'MODERATE RISK'
        WHEN ROUND((liquidity_risk + funding_risk + price_gap_risk)/3 * 100, 2) > 30 THEN 'LOW RISK'
        ELSE 'SAFE'
    END AS risk_tier

FROM token_risks
ORDER BY composite_risk_score DESC;


""").show(truncate=False)
# Out:
# +----------+---------------+--------------+-----------+----------+----------+--------------+------------+--------------+--------------------+-------------+
# |baseSymbol|openInterestUSD|usdVolume24h  |fundingRate|price     |markPrice |liquidity_risk|funding_risk|price_gap_risk|composite_risk_score|risk_tier    |
# +----------+---------------+--------------+-----------+----------+----------+--------------+------------+--------------+--------------------+-------------+
# |BONK.P    |1768.23624672  |36407.83796539|-0.000014  |0.00000864|0.00000867|98.5          |100.0       |0.0           |66.17               |MODERATE RISK|
# |FARTCOIN.P|0.08404        |347.18889     |0.000005   |0.2101    |0.21      |100.0         |25.0        |0.0           |41.67               |LOW RISK     |
# |GRASS.P   |1.95518        |202.97898     |0.000003   |0.3371    |0.3417    |99.7          |8.33        |0.0           |36.01               |LOW RISK     |
# |JUP.P     |20016.9736     |6889.55584    |-0.000003  |0.2392    |0.239     |9.2           |8.33        |0.0           |5.84                |SAFE         |
# |JTO.P     |934.96104      |292.30815     |-0.000002  |0.4646    |0.4651    |0.0           |0.0         |0.0           |0.0                 |SAFE         |
# +----------+---------------+--------------+-----------+----------+----------+--------------+------------+--------------+--------------------+-------------+

# %% [markdown]
# The weights for the risk score components were chosen to emphasize factors that are more indicative of potential rug pulls:
#
# * low open interest (OI, signals thin depth/easy dumps),
# * extreme positive funding rates (retail traps),
# * low 24h volume (illiquidity),
# * high OI/volume ratio (wash trading),
# * price/mark gap (manipulation).

# %%
df_solana_contracts_test = spark.sql("""
SELECT
    c.*,
    from_unixtime(nextFundingTime / 1000000) AS nextFundingTimestamp_transformed
FROM contracts c
JOIN solana_tokens_distinct s
  ON c.baseSymbol LIKE CONCAT(s.symbol, '%')
  order by baseSymbol
""")

df_solana_contracts_test.createOrReplaceTempView("solana_contracts_view_test")

df_solana_contracts_test.show(truncate=False)
# Out:
# +----------+-----------+----------+-------------+-------------+----------+----------+---------------+----------------+--------------+----------------+----------+-----------+-----------+-----------+--------------+------------------+--------------+----------+--------------------------------+
# |baseSymbol|fundingRate|high24h   |indexCurrency|indexPrice   |low24h    |markPrice |nextFundingRate|nextFundingTime |openInterest  |openInterestUSD |price     |price24hAgo|productType|quoteSymbol|quoteVolume24h|symbol            |usdVolume24h  |volume24h |nextFundingTimestamp_transformed|
# +----------+-----------+----------+-------------+-------------+----------+----------+---------------+----------------+--------------+----------------+----------+-----------+-----------+-----------+--------------+------------------+--------------+----------+--------------------------------+
# |BONK.P    |-0.000011  |0.00000959|USDT         |0.000008678  |0.00000846|0.00000867|-0.000014      |1763794800000000|204656973     |1768.23624672   |0.00000864|0.00000954 |perpetual  |USDT       |36407.83796539|BONK_USDT_PERP    |36407.83796539|4072703476|2025-11-22 07:00:00             |
# |FARTCOIN.P|0.000006   |0.2496    |USDT         |0.210017672  |0.2034    |0.21      |0.000005       |1763794800000000|0.4           |0.08404         |0.2101    |0.2485     |perpetual  |USDT       |347.18889     |FARTCOIN_USDT_PERP|347.18889     |1526.9    |2025-11-22 07:00:00             |
# |GRASS.P   |0.000001   |0.5026    |USDT         |0.342169098  |0.3245    |0.3417    |0.000003       |1763794800000000|5.8           |1.95518         |0.3371    |0.4851     |perpetual  |USDT       |202.97898     |GRASS_USDT_PERP   |202.97898     |524.6     |2025-11-22 07:00:00             |
# |JTO.P     |-0.000008  |0.5109    |USDT         |0.46501125   |0.4519    |0.4651    |-0.000002      |1763794800000000|2012.4        |934.96104       |0.4646    |0.5092     |perpetual  |USDT       |292.30815     |JTO_USDT_PERP     |292.30815     |609.1     |2025-11-22 07:00:00             |
# |JUP.P     |-0.000002  |0.2515    |USDT         |0.239055924  |0.2277    |0.239     |-0.000003      |1763794800000000|83683         |20016.9736      |0.2392    |0.2502     |perpetual  |USDT       |6889.55584    |JUP_USDT_PERP     |6889.55584    |28521.8   |2025-11-22 07:00:00             |
# |MELANIA.P |-0.000032  |0.1285    |USDT         |0.122044014  |0.1163    |0.1223    |-0.000002      |1763794800000000|170545.809    |20755.4249553   |0.1217    |0.1282     |perpetual  |USDT       |1264.1979427  |MELANIA_USDT_PERP |1264.1979427  |10235.564 |2025-11-22 07:00:00             |
# |PENGU.P   |-0.000023  |0.011279  |USDT         |0.010364756  |0.010012  |0.010358  |-0.000028      |1763794800000000|585.8         |6.0144086       |0.010267  |0.011278   |perpetual  |USDT       |382.1371473   |PENGU_USDT_PERP   |382.1371473   |36501.2   |2025-11-22 07:00:00             |
# |POPCAT.P  |0.000008   |0.10111   |USDT         |0.089550505  |0.08403   |0.08958   |-0.000004      |1763794800000000|16            |1.42432         |0.08902   |0.10078    |perpetual  |USDT       |370.97893     |POPCAT_USDT_PERP  |370.97893     |3987      |2025-11-22 07:00:00             |
# |PUMP.P    |0.000012   |0.002909  |USDT         |0.002735117  |0.002627  |0.002734  |-0.00003       |1763794800000000|2054525       |5530.7813       |0.002692  |0.002909   |perpetual  |USDT       |6582.439279   |PUMP_USDT_PERP    |6582.439279   |2444274   |2025-11-22 07:00:00             |
# |PYTH.P    |-0.000019  |0.07955   |USDT         |0.07298961   |0.07118   |0.07293   |-0.000024      |1763794800000000|2678.72       |193.2964352     |0.07216   |0.07894    |perpetual  |USDT       |319.993558    |PYTH_USDT_PERP    |319.993558    |4309.67   |2025-11-22 07:00:00             |
# |RENDER.P  |-0.000012  |1.877     |USDT         |1.68199256   |1.637     |1.681     |-0.000012      |1763794800000000|23909.2       |39952.2732      |1.671     |1.87       |perpetual  |USDT       |4226.56728    |RENDER_USDT_PERP  |4226.56728    |2481.45   |2025-11-22 07:00:00             |
# |SOL.P     |-0.000019  |131.16    |USDT         |127.994904871|121.66    |127.93    |-0.000017      |1763794800000000|1157.744024824|147577.630844315|127.47    |131.16     |perpetual  |USDT       |296850.46225  |SOL_USDT_PERP     |296850.46225  |2345.428  |2025-11-22 07:00:00             |
# |TRUMP.P   |-0.000009  |6.614     |USDT         |6.337263766  |6.051     |6.334     |-0.000013      |1763794800000000|918.053       |5788.324165     |6.305     |6.612      |perpetual  |USDT       |12084.610604  |TRUMP_USDT_PERP   |12084.610604  |1924.026  |2025-11-22 07:00:00             |
# |WIF.P     |-0.000003  |0.3756    |USDT         |0.319297926  |0.3107    |0.3193    |0.000003       |1763794800000000|53959.875     |17170.032225    |0.3182    |0.3749     |perpetual  |USDT       |30165.106897  |WIF_USDT_PERP     |30165.106897  |87438.91  |2025-11-22 07:00:00             |
# +----------+-----------+----------+-------------+-------------+----------+----------+---------------+----------------+--------------+----------------+----------+-----------+-----------+-----------+--------------+------------------+--------------+----------+--------------------------------+

# %% [markdown]
# # Test

# %%
def get_rug_pull_risk_test(spark):
    query = """
WITH stats AS (
    -- Compute min/max values for normalization
    SELECT
        MIN(openInterestUSD / NULLIF(usdVolume24h, 0)) AS min_ratio,
        MAX(openInterestUSD / NULLIF(usdVolume24h, 0)) AS max_ratio,
        MIN(ABS(nextFundingRate)) AS min_funding,
        MAX(ABS(nextFundingRate)) AS max_funding,
        MIN(ABS(price - markPrice)/NULLIF(markPrice,0)) AS min_price_gap,
        MAX(ABS(price - markPrice)/NULLIF(markPrice,0)) AS max_price_gap
    FROM solana_contracts_view_test
),
token_risks AS (
    SELECT
        c.baseSymbol,
        c.openInterestUSD,
        c.usdVolume24h,
        c.nextFundingRate AS fundingRate,
        c.price,
        c.markPrice,
        s.min_ratio,
        s.max_ratio,
        s.min_funding,
        s.max_funding,
        s.min_price_gap,
        s.max_price_gap,

        -- Liquidity risk: smaller OI → higher risk, clamped 0–1
        ROUND(
            1 - CASE
                WHEN c.usdVolume24h > 0 THEN
                    ( (c.openInterestUSD / c.usdVolume24h) - min_ratio )
                    / NULLIF((max_ratio - min_ratio), 0)
                ELSE
                    1  -- no volume = extremely illiquid = highest risk
            END,
        3
        ) AS liquidity_risk,

        -- Funding risk: scaled 0–1
        GREATEST(0, LEAST(1,
            CASE WHEN s.max_funding > s.min_funding THEN
                (ABS(c.nextFundingRate) - s.min_funding) / (s.max_funding - s.min_funding)
            ELSE 0 END
        )) AS funding_risk,

        -- Price gap risk: scaled 0–1
        GREATEST(0, LEAST(1,
            CASE WHEN s.max_price_gap > s.min_price_gap THEN
                (ABS(c.price - c.markPrice)/NULLIF(c.markPrice,0) - s.min_price_gap) / (s.max_price_gap - s.min_price_gap)
            ELSE 0 END
        )) AS price_gap_risk
    FROM solana_contracts_view_test c
    CROSS JOIN stats s
)

SELECT
    baseSymbol,
    openInterestUSD,
    usdVolume24h,
    fundingRate,
    price,
    markPrice,
    ROUND(liquidity_risk * 100, 2) AS liquidity_risk,
    ROUND(funding_risk * 100, 2) AS funding_risk,
    ROUND(price_gap_risk * 100, 2) AS price_gap_risk,

    -- Composite risk: average of three components, scaled 0–100
    ROUND((liquidity_risk + funding_risk + price_gap_risk)/3 * 100, 2) AS composite_risk_score,

    -- Risk tier classification
    CASE
        WHEN ROUND((liquidity_risk + funding_risk + price_gap_risk)/3 * 100, 2)  > 80 THEN 'HIGH RISK'
        WHEN ROUND((liquidity_risk + funding_risk + price_gap_risk)/3 * 100, 2)  > 60 THEN 'MODERATE RISK'
        WHEN ROUND((liquidity_risk + funding_risk + price_gap_risk)/3 * 100, 2) > 40 THEN 'LOW RISK'
        ELSE 'SAFE'
    END AS risk_tier

FROM token_risks
ORDER BY composite_risk_score DESC;
    """

    return spark.sql(query)

# %%
risk_results = get_rug_pull_risk_test(spark)
risk_results.show(truncate=False)
# Out:
# +----------+----------------+--------------+-----------+----------+----------+--------------+------------+--------------+--------------------+-------------+
# |baseSymbol|openInterestUSD |usdVolume24h  |fundingRate|price     |markPrice |liquidity_risk|funding_risk|price_gap_risk|composite_risk_score|risk_tier    |
# +----------+----------------+--------------+-----------+----------+----------+--------------+------------+--------------+--------------------+-------------+
# |PUMP.P    |5530.7813       |6582.439279   |-0.00003   |0.002692  |0.002734  |94.9          |100.0       |100.0         |98.3                |HIGH RISK    |
# |PENGU.P   |6.0144086       |382.1371473   |-0.000028  |0.010267  |0.010358  |99.9          |92.86       |100.0         |97.59               |HIGH RISK    |
# |PYTH.P    |193.2964352     |319.993558    |-0.000024  |0.07216   |0.07293   |96.3          |78.57       |100.0         |91.62               |HIGH RISK    |
# |BONK.P    |1768.23624672   |36407.83796539|-0.000014  |0.00000864|0.00000867|99.7          |42.86       |100.0         |80.85               |HIGH RISK    |
# |FARTCOIN.P|0.08404         |347.18889     |0.000005   |0.2101    |0.21      |100.0         |10.71       |100.0         |70.24               |MODERATE RISK|
# |POPCAT.P  |1.42432         |370.97893     |-0.000004  |0.08902   |0.08958   |100.0         |7.14        |100.0         |69.05               |MODERATE RISK|
# |GRASS.P   |1.95518         |202.97898     |0.000003   |0.3371    |0.3417    |99.9          |3.57        |100.0         |67.82               |MODERATE RISK|
# |WIF.P     |17170.032225    |30165.106897  |0.000003   |0.3182    |0.3193    |96.5          |3.57        |100.0         |66.69               |MODERATE RISK|
# |JUP.P     |20016.9736      |6889.55584    |-0.000003  |0.2392    |0.239     |82.3          |3.57        |100.0         |61.96               |MODERATE RISK|
# |JTO.P     |934.96104       |292.30815     |-0.000002  |0.4646    |0.4651    |80.5          |0.0         |100.0         |60.17               |MODERATE RISK|
# |TRUMP.P   |5788.324165     |12084.610604  |-0.000013  |6.305     |6.334     |97.1          |39.29       |41.76         |59.38               |LOW RISK     |
# |RENDER.P  |39952.2732      |4226.56728    |-0.000012  |1.671     |1.681     |42.4          |35.71       |100.0         |59.37               |LOW RISK     |
# |SOL.P     |147577.630844315|296850.46225  |-0.000017  |127.47    |127.93    |97.0          |53.57       |0.0           |50.19               |LOW RISK     |
# |MELANIA.P |20755.4249553   |1264.1979427  |-0.000002  |0.1217    |0.1223    |0.0           |0.0         |100.0         |33.33               |SAFE         |
# +----------+----------------+--------------+-----------+----------+----------+--------------+------------+--------------+--------------------+-------------+

# %% [markdown]
# # Summary (1):
#
# ### Insights or Next Steps
# *   The updated risk assessment provides a more robust and targeted approach to identifying potential rug pulls by giving higher importance to Open Interest and Funding Rate, and by specifically penalizing extreme positive funding rates, which often precede coordinated dumps. The shift to absolute risk tiers ensures consistent and transparent classification across all tokens, making the risk levels more interpretable.

# %% [markdown]
# # Token concentration

# %%
BASE_URL = "https://api.arkhamintelligence.com"

def get_token_holders(token_address, chain="solana", group_by_entity=False):
    """
    Get top holders for a token on a specified chain.

    Args:
        token_address: The token's contract address
        chain: Blockchain (default "solana")
        group_by_entity: If True, group results by entity
    """

    url = f"{BASE_URL}/token/holders/{chain}/{token_address}"

    headers = {
        "API-Key": ARKHAM_API_KEY
    }

    params = {
        "groupByEntity": str(group_by_entity).lower()  # API expects "true" or "false"
    }

    response = requests.get(url, headers=headers, params=params)

    if response.status_code == 200:
        return response.json()
    else:
        print(f"Error: {response.status_code} for token {token_address}")
        print(response.text)
        return None

# %%
# ==========================
# Initialize Spark
# ==========================
spark = SparkSession.builder.appName("ArkhamHolderAnalysis").getOrCreate()


# ==========================
# 1. PARSE API JSON INTO DATAFRAME (for ONE token)
# ==========================
def parse_holders_to_dataframe(json_data):
    holders_list = json_data.get('addressTopHolders', {}).get('solana', [])
    total_supply = json_data.get('totalSupply', {}).get('solana', 0)
    token_info = json_data.get('token', {})

    flattened = []
    for h in holders_list:
        flattened.append({
            'address': h['address']['address'],
            'balance': float(h['balance']),
            'usd_value': float(h['usd']),
            'pct_of_cap': float(h['pctOfCap']),
            'entity_name': h['address'].get('arkhamEntity', {}).get('name'),
            'entity_type': h['address'].get('arkhamEntity', {}).get('type'),
            'label_name': h['address'].get('arkhamLabel', {}).get('name'),
            'chain': h['address']['chain'],
            'token_address': token_info['identifier']['address'],
            'token_name': token_info['name'],
            'token_symbol': token_info['symbol'],
            'total_supply': total_supply
        })

    return spark.createDataFrame(flattened)


# ==========================
# 2. FETCH MULTIPLE TOKENS AND UNION ALL
# ==========================

token_list = [
    "EPjFWdd5AufqSSqeM2qN1xzybapC8G4wEGGkZwyTDt1v",      # Established stablecoin
    "So11111111111111111111111111111111111111112",      # Native SOL token
    "9BB6NFEcjBCtnNLFko2FqVQBq8HHM13kCyYcdQbgpump",      # Fartcoin
    "7xKXtg2CW87d97TXJSDpbD5jBkheTqA83TZRuJosgAsU",     # Samoyedcoin
    "JUPyiwrYJFskUPiHa7hkeR8VUtAeFoSYbKedZNsDvCN",       #Jupiter
    "DezXAZ8z7PnrnRJjz3wXBoRgixCa6xjnB7YaB1pPB263",      #Bonk
    "2zMMhcVQEXDtdE6vsFS7S7D5oUodfJHE8vd1gnBouauv",      #Pengu
    "9jZgvgS2bWtQiYzv48GcWzY4tnkeRSANbTm8Kp1LmSyS"       #Sharpe (Real Rug pull)
]

dfs = []

for addr in token_list:
    data = get_token_holders(addr)
    if data:
        df = parse_holders_to_dataframe(data)
        dfs.append(df)

# Combine all tokens using union
all_holders_df = reduce(DataFrame.unionByName, dfs)

# Register for SQL
all_holders_df.createOrReplaceTempView("token_holders")

# %%
test = """ SELECT * FROM token_holders """
spark.sql(test).show(truncate=False)
# Out:
# +--------------------------------------------+------------------+------+-------------------------+---------------------+--------------------------------+---------------------+--------------------------------------------+----------+------------+-------------------+------------------+
# |address                                     |balance           |chain |entity_name              |entity_type          |label_name                      |pct_of_cap           |token_address                               |token_name|token_symbol|total_supply       |usd_value         |
# +--------------------------------------------+------------------+------+-------------------------+---------------------+--------------------------------+---------------------+--------------------------------------------+----------+------------+-------------------+------------------+
# |7VHUFJHWu2CuExkJcJrzhQPJ2oygupTWkL2A2For4BmE|8.44180586825984E8|solana|Circle                   |stablecoin           |NULL                            |0.011401098899011513 |EPjFWdd5AufqSSqeM2qN1xzybapC8G4wEGGkZwyTDt1v|USD Coin  |usdc        |8.835011403104708E9|8.44180586825984E8|
# |5tzFkiKscXHK5ZXCGbXZxdw7gTjjD1mBwuoFbhUvuAi9|6.0893711325738E8 |solana|Binance                  |cex                  |Hot Wallet                      |0.008224013155323926 |EPjFWdd5AufqSSqeM2qN1xzybapC8G4wEGGkZwyTDt1v|USD Coin  |usdc        |8.835011403104708E9|6.0893711325738E8 |
# |AVzP2GeRmqGphJsMxWoqjpUifPpCret7LqWhD8NWQK49|2.44979518687089E8|solana|Jupiter                  |dex-aggregator       |Perpetuals Vault Authority      |0.0033085761084428794|EPjFWdd5AufqSSqeM2qN1xzybapC8G4wEGGkZwyTDt1v|USD Coin  |usdc        |8.835011403104708E9|2.44979518687089E8|
# |8Vkgsarud8mSc1gkzayGA7XhNQfq4wDJRxTWDgq8RaJD|2.10000122012701E8|solana|Bullish.com              |cex                  |Cold Wallet                     |0.0028361611214886015|EPjFWdd5AufqSSqeM2qN1xzybapC8G4wEGGkZwyTDt1v|USD Coin  |usdc        |8.835011403104708E9|2.10000122012701E8|
# |9d9mb8kooFfaD3SctgZtkxQypkshx6ezhbKio89ixyy2|1.73440480316777E8|solana|Meteora (Prev. Mercurial)|dex                  |Market                          |0.002342404101731908 |EPjFWdd5AufqSSqeM2qN1xzybapC8G4wEGGkZwyTDt1v|USD Coin  |usdc        |8.835011403104708E9|1.73440480316777E8|
# |HGRErGQVy9JyJ2JsSp2uj32DBXMYbSDAGixc482jAFxp|1.50010799040099E8|solana|pump.fun                 |meme                 |Squads Vault "Token Cold SOL1"  |0.0020259740421257303|EPjFWdd5AufqSSqeM2qN1xzybapC8G4wEGGkZwyTDt1v|USD Coin  |usdc        |8.835011403104708E9|1.50010799040099E8|
# |G9XbC9ggrBYogsZgKYf2pnTvPnJ9z5Zd6WG8BuyioTA9|1.49999755000243E8|solana|pump.fun                 |meme                 |Squads Vault "Token Secure SOL1"|0.0020258248866101836|EPjFWdd5AufqSSqeM2qN1xzybapC8G4wEGGkZwyTDt1v|USD Coin  |usdc        |8.835011403104708E9|1.49999755000243E8|
# |4jtZwKHXD7vToiiPyqwa9467FQc19Mcy62wSFHijZqqE|1.35262519253173E8|solana|pump.fun                 |meme                 |Squads Vault "Coin 1 SOL3"      |0.001826790835279851 |EPjFWdd5AufqSSqeM2qN1xzybapC8G4wEGGkZwyTDt1v|USD Coin  |usdc        |8.835011403104708E9|1.35262519253173E8|
# |DBD8hAwLDRQkTsu6EqviaYNGKPnsAMmQonxf7AH8ZcFY|1.19860845276021E8|solana|Circle                   |stablecoin           |CCTP Token Minter               |0.0016187831992785762|EPjFWdd5AufqSSqeM2qN1xzybapC8G4wEGGkZwyTDt1v|USD Coin  |usdc        |8.835011403104708E9|1.19860845276021E8|
# |7s1da8DduuBFqGra5bJBjpnvL5E9mGzCuMk1Qkh4or2Z|1.06791646543405E8|solana|Jupiter                  |dex-aggregator       |Supply Vault Owner              |0.0014422768573812519|EPjFWdd5AufqSSqeM2qN1xzybapC8G4wEGGkZwyTDt1v|USD Coin  |usdc        |8.835011403104708E9|1.06791646543405E8|
# |7aq6Jka4kHUnuvU6v14npvSCosurThVYf47zRPFMProZ|1.0000000009E8    |solana|NULL                     |NULL                 |Coinbase Deposit                |0.0013505521315219109|EPjFWdd5AufqSSqeM2qN1xzybapC8G4wEGGkZwyTDt1v|USD Coin  |usdc        |8.835011403104708E9|1.0000000009E8    |
# |JCNCMFXo5M5qwUPg2Utu1u6YWp3MbygxqBsBeXXJfrw |7.6521465881556E7 |solana|Drift Protocol           |derivatives          |Vault                           |0.0010334622876050502|EPjFWdd5AufqSSqeM2qN1xzybapC8G4wEGGkZwyTDt1v|USD Coin  |usdc        |8.835011403104708E9|7.6521465881556E7 |
# |3csuXZKah5rgpb8RiwX9XfjrMxcp3u1K9mBdCwL51spj|7.2717112840508E7 |solana|pump.fun                 |meme                 |Squads Vault "New Cold SOL1"    |9.820825165647996E-4 |EPjFWdd5AufqSSqeM2qN1xzybapC8G4wEGGkZwyTDt1v|USD Coin  |usdc        |8.835011403104708E9|7.2717112840508E7 |
# |41zCUJsKk6cMB94DDtm99qWmyMZfp4GkAhhuz4xTwePu|7.2185054481386E7 |solana|Circle                   |stablecoin           |Treasury                        |9.748967910612041E-4 |EPjFWdd5AufqSSqeM2qN1xzybapC8G4wEGGkZwyTDt1v|USD Coin  |usdc        |8.835011403104708E9|7.2185054481386E7 |
# |6FEVkH17P9y8Q9aCkDdPcMDjvj7SVxrTETaYEm8f51Jy|7.2103890166528E7 |solana|Crypto.com               |cex                  |Hot Wallet                      |9.738006246778407E-4 |EPjFWdd5AufqSSqeM2qN1xzybapC8G4wEGGkZwyTDt1v|USD Coin  |usdc        |8.835011403104708E9|7.2103890166528E7 |
# |Bc5bth4Mn2n8DX1etZwvnq3uDEGg479s2D24TCEsnXHf|6.6903540704752E7 |solana|Bullish.com              |cex                  |Hot Wallet                      |9.035671942384468E-4 |EPjFWdd5AufqSSqeM2qN1xzybapC8G4wEGGkZwyTDt1v|USD Coin  |usdc        |8.835011403104708E9|6.6903540704752E7 |
# |9DrvZvyWh1HuAoZxvYWMvkf2XCzryCpGgHqrMjyDWpmo|6.0379334816847E7 |solana|Kamino Finance           |lending-decentralized|Reserve                         |8.154543926337693E-4 |EPjFWdd5AufqSSqeM2qN1xzybapC8G4wEGGkZwyTDt1v|USD Coin  |usdc        |8.835011403104708E9|6.0379334816847E7 |
# |3Ln6KEgLoMR2xFHfqtYazP7CxFQPDtUVVtwCVsLKVfmV|5.7948766366015E7 |solana|BingX                    |cex                  |Cold Wallet                     |7.826282986425023E-4 |EPjFWdd5AufqSSqeM2qN1xzybapC8G4wEGGkZwyTDt1v|USD Coin  |usdc        |8.835011403104708E9|5.7948766366015E7 |
# |HPvAiC7pJdE136t7YrNTUJ5on5NNqhcUr4onLiJYteUe|4.7305048726905E7 |solana|NULL                     |NULL                 |NULL                            |6.388793433237027E-4 |EPjFWdd5AufqSSqeM2qN1xzybapC8G4wEGGkZwyTDt1v|USD Coin  |usdc        |8.835011403104708E9|4.7305048726905E7 |
# |6LY1JzAFVZsP2a2xKrtU6znQMQ5h4i7tocWdgrkZzkzF|4.729264989005E7  |solana|Kraken                   |cex                  |Hot Wallet                      |6.387118905684242E-4 |EPjFWdd5AufqSSqeM2qN1xzybapC8G4wEGGkZwyTDt1v|USD Coin  |usdc        |8.835011403104708E9|4.729264989005E7  |
# +--------------------------------------------+------------------+------+-------------------------+---------------------+--------------------------------+---------------------+--------------------------------------------+----------+------------+-------------------+------------------+
# only showing top 20 rows

# %%
# ==========================
# CONCENTRATION RISK ANALYSIS SQL
# ==========================
risk_analysis_query = """
WITH holder_stats AS (
    SELECT
        token_address,
        token_name,
        token_symbol,
        total_supply,
        COUNT(*) AS num_holders_shown,
        MAX(pct_of_cap) AS largest_holder_pct,
        APPROX_PERCENTILE(pct_of_cap, 0.5) AS median_holder_pct,
        AVG(pct_of_cap) AS avg_holder_pct,
        SUM(CASE WHEN entity_type = 'cex' THEN pct_of_cap ELSE 0 END) AS cex_concentration,
        SUM(CASE WHEN entity_type IN ('dex', 'dex-aggregator') THEN pct_of_cap ELSE 0 END) AS dex_concentration,
        SUM(CASE WHEN entity_type IS NULL THEN pct_of_cap ELSE 0 END) AS unknown_concentration
    FROM token_holders
    GROUP BY token_address, token_name, token_symbol, total_supply
),
top_concentrations AS (
    SELECT
        token_address,
        SUM(CASE WHEN rn <= 5  THEN pct_of_cap END) AS top_5_pct,
        SUM(CASE WHEN rn <= 10 THEN pct_of_cap END) AS top_10_pct
    FROM (
        SELECT
            token_address,
            pct_of_cap,
            ROW_NUMBER() OVER (PARTITION BY token_address ORDER BY pct_of_cap DESC) AS rn
        FROM token_holders
    ) ranked
    GROUP BY token_address
),
base AS (
    SELECT
        hs.*,
        tc.top_5_pct,
        tc.top_10_pct
    FROM holder_stats hs
    JOIN top_concentrations tc ON hs.token_address = tc.token_address
),
normalized AS (
    SELECT
        *,
        MIN(top_10_pct)     OVER () AS min_top10,
        MAX(top_10_pct)     OVER () AS max_top10,
        MIN(unknown_concentration) OVER () AS min_unknown,
        MAX(unknown_concentration) OVER () AS max_unknown,
        MIN(largest_holder_pct)    OVER () AS min_whale,
        MAX(largest_holder_pct)    OVER () AS max_whale
    FROM base
),
scored AS (
    SELECT
        *,
        GREATEST(0, LEAST(1, (top_10_pct - min_top10) / NULLIF(max_top10 - min_top10,0))) AS norm_concentration,
        GREATEST(0, LEAST(1, (unknown_concentration - min_unknown) / NULLIF(max_unknown - min_unknown,0))) AS norm_unknown,
        GREATEST(0, LEAST(1, (largest_holder_pct - min_whale) / NULLIF(max_whale - min_whale,0))) AS norm_whale
    FROM normalized
)
SELECT
    token_address,
    token_name,
    token_symbol,
    num_holders_shown,
    ROUND(largest_holder_pct * 100, 2) AS largest_holder_pct,
    ROUND(top_10_pct * 100, 2) AS top_10_concentration_pct,
    ROUND(top_5_pct * 100, 2) AS top_5_concentration_pct,
    ROUND(cex_concentration * 100, 2) AS cex_concentration_pct,
    ROUND(dex_concentration * 100, 2) AS dex_concentration_pct,
    ROUND(unknown_concentration * 100, 2) AS unknown_concentration_pct,
    ROUND(
        (norm_concentration * 0.45 +
         norm_unknown       * 0.30 +
         norm_whale         * 0.25) * 100, 2
    ) AS composite_risk_score,
    CASE
        WHEN (norm_concentration * 0.45 + norm_unknown * 0.30 + norm_whale * 0.25) > 0.70 THEN 'HIGH RISK'
        WHEN (norm_concentration * 0.45 + norm_unknown * 0.30 + norm_whale * 0.25) > 0.40 THEN 'MEDIUM RISK'
        WHEN (norm_concentration * 0.45 + norm_unknown * 0.30 + norm_whale * 0.25) > 0.15 THEN 'LOW RISK'
        ELSE 'VERY LOW RISK'
    END AS risk_tier
FROM scored
ORDER BY composite_risk_score DESC
"""

risk_analysis_df = spark.sql(risk_analysis_query)


# ==========================
# REPORTS
# ==========================
print("=" * 80)
print("HOLDER CONCENTRATION RISK ANALYSIS")
print("=" * 80)
risk_analysis_df.show(truncate=False, vertical=True)


holder_breakdown_query = """
SELECT
    token_name,
    entity_type,
    COUNT(*) as num_holders,
    SUM(pct_of_cap) * 100 as total_pct_held,
    AVG(balance) as avg_balance,
    SUM(usd_value) as total_usd_value
FROM token_holders
GROUP BY token_name, entity_type
ORDER BY token_name asc, total_pct_held DESC
"""

holder_breakdown_df = spark.sql(holder_breakdown_query)

print("\n" + "=" * 80)
print("HOLDER BREAKDOWN BY ENTITY TYPE")
print("=" * 80)
holder_breakdown_df.show(holder_breakdown_df.count(), truncate=False)


top_holders_query = """
SELECT
    token_name,
    address,
    entity_name,
    entity_type,
    label_name,
    ROUND(pct_of_cap * 100, 2) AS pct_of_supply,
    ROUND(balance, 2) AS balance,
    ROUND(usd_value, 2) AS usd_value
FROM (
    SELECT
        *,
        ROW_NUMBER() OVER (
            PARTITION BY token_name
            ORDER BY pct_of_cap DESC
        ) AS rn
    FROM token_holders
)
WHERE rn <= 20
ORDER BY token_name, pct_of_cap DESC;
"""

top_holders_df = spark.sql(top_holders_query)

print("\n" + "=" * 80)
print("TOP 20 HOLDERS")
print("=" * 80)
top_holders_df.show(top_holders_df.count(), truncate=False)


# Return all dataframes
result = {
    'risk_analysis': risk_analysis_df,
    'holder_breakdown': holder_breakdown_df,
    'top_holders': top_holders_df,
    'all_holders': all_holders_df
}
# Out:
# ================================================================================
# HOLDER CONCENTRATION RISK ANALYSIS
# ================================================================================
# -RECORD 0-----------------------------------------------------------------
#  token_address             | 9jZgvgS2bWtQiYzv48GcWzY4tnkeRSANbTm8Kp1LmSyS
#  token_name                | SHARPEI
#  token_symbol              | shar
#  num_holders_shown         | 100
#  largest_holder_pct        | 97.98
#  top_10_concentration_pct  | 98.82
#  top_5_concentration_pct   | 98.49
#  cex_concentration_pct     | 0.0
#  dex_concentration_pct     | 98.03
#  unknown_concentration_pct | 1.52
#  composite_risk_score      | 70.12
#  risk_tier                 | HIGH RISK
# -RECORD 1-----------------------------------------------------------------
#  token_address             | JUPyiwrYJFskUPiHa7hkeR8VUtAeFoSYbKedZNsDvCN
#  token_name                | Jupiter
#  token_symbol              | jup
#  num_holders_shown         | 100
#  largest_holder_pct        | 25.71
#  top_10_concentration_pct  | 72.03
#  top_5_concentration_pct   | 63.08
#  cex_concentration_pct     | 6.53
#  dex_concentration_pct     | 68.81
#  unknown_concentration_pct | 10.03
#  composite_risk_score      | 46.24
#  risk_tier                 | MEDIUM RISK
# -RECORD 2-----------------------------------------------------------------
#  token_address             | 9BB6NFEcjBCtnNLFko2FqVQBq8HHM13kCyYcdQbgpump
#  token_name                | Fartcoin
#  token_symbol              | fartcoin
#  num_holders_shown         | 100
#  largest_holder_pct        | 7.14
#  top_10_concentration_pct  | 32.83
#  top_5_concentration_pct   | 23.53
#  cex_concentration_pct     | 25.09
#  dex_concentration_pct     | 3.26
#  unknown_concentration_pct | 35.64
#  composite_risk_score      | 45.32
#  risk_tier                 | MEDIUM RISK
# -RECORD 3-----------------------------------------------------------------
#  token_address             | 2zMMhcVQEXDtdE6vsFS7S7D5oUodfJHE8vd1gnBouauv
#  token_name                | Pudgy Penguins
#  token_symbol              | pengu
#  num_holders_shown         | 100
#  largest_holder_pct        | 15.69
#  top_10_concentration_pct  | 58.47
#  top_5_concentration_pct   | 41.64
#  cex_concentration_pct     | 28.83
#  dex_concentration_pct     | 0.54
#  unknown_concentration_pct | 6.54
#  composite_risk_score      | 34.18
#  risk_tier                 | LOW RISK
# -RECORD 4-----------------------------------------------------------------
#  token_address             | DezXAZ8z7PnrnRJjz3wXBoRgixCa6xjnB7YaB1pPB263
#  token_name                | Bonk
#  token_symbol              | bonk
#  num_holders_shown         | 100
#  largest_holder_pct        | 7.47
#  top_10_concentration_pct  | 34.51
#  top_5_concentration_pct   | 25.02
#  cex_concentration_pct     | 39.79
#  dex_concentration_pct     | 0.0
#  unknown_concentration_pct | 16.42
#  composite_risk_score      | 29.37
#  risk_tier                 | LOW RISK
# -RECORD 5-----------------------------------------------------------------
#  token_address             | 7xKXtg2CW87d97TXJSDpbD5jBkheTqA83TZRuJosgAsU
#  token_name                | Samoyed Coin
#  token_symbol              | samo
#  num_holders_shown         | 100
#  largest_holder_pct        | 8.35
#  top_10_concentration_pct  | 32.31
#  top_5_concentration_pct   | 22.13
#  cex_concentration_pct     | 27.56
#  dex_concentration_pct     | 4.47
#  unknown_concentration_pct | 16.43
#  composite_risk_score      | 28.57
#  risk_tier                 | LOW RISK
# -RECORD 6-----------------------------------------------------------------
#  token_address             | So11111111111111111111111111111111111111112
#  token_name                | Wrapped Solana
#  token_symbol              | sol
#  num_holders_shown         | 100
#  largest_holder_pct        | 10.11
#  top_10_concentration_pct  | 30.97
#  top_5_concentration_pct   | 26.48
#  cex_concentration_pct     | 0.0
#  dex_concentration_pct     | 30.32
#  unknown_concentration_pct | 1.52
#  composite_risk_score      | 15.33
#  risk_tier                 | LOW RISK
# -RECORD 7-----------------------------------------------------------------
#  token_address             | EPjFWdd5AufqSSqeM2qN1xzybapC8G4wEGGkZwyTDt1v
#  token_name                | USD Coin
#  token_symbol              | usdc
#  num_holders_shown         | 100
#  largest_holder_pct        | 1.14
#  top_10_concentration_pct  | 3.71
#  top_5_concentration_pct   | 2.81
#  cex_concentration_pct     | 1.53
#  dex_concentration_pct     | 0.87
#  unknown_concentration_pct | 1.39
#  composite_risk_score      | 0.0
#  risk_tier                 | VERY LOW RISK
#
#
# ================================================================================
# HOLDER BREAKDOWN BY ENTITY TYPE
# ================================================================================
# +--------------+---------------------+-----------+--------------------+---------------------+--------------------+
# |token_name    |entity_type          |num_holders|total_pct_held      |avg_balance          |total_usd_value     |
# +--------------+---------------------+-----------+--------------------+---------------------+--------------------+
# |Bonk          |cex                  |58         |39.79049695360013   |6.036855305784558E11 |3.028690306912112E8 |
# |Bonk          |NULL                 |36         |16.41638344600552   |4.0126786736680316E11|1.2495481389802253E8|
# |Bonk          |meme                 |3          |9.317414827140883   |2.7329618775212397E12|7.092036072167616E7 |
# |Bonk          |fund                 |1          |2.5681845245203485  |2.2598812643317324E12|1.9547972936469488E7|
# |Bonk          |lending-decentralized|1          |0.8012853879649722  |7.050933522711041E11 |6099057.49714505    |
# |Bonk          |bridge               |1          |0.7153417273307743  |6.294669840717307E11 |5444889.41222047    |
# |Fartcoin      |NULL                 |74         |35.642906382264236  |4816524.131106499    |7.067828198189731E7 |
# |Fartcoin      |cex                  |20         |25.09327416094601   |1.2546416084738549E7 |4.97588352637514E7  |
# |Fartcoin      |blockchain-infra     |1          |7.135555339780172   |7.1354296545242E7    |1.4149485650624944E7|
# |Fartcoin      |dex                  |2          |2.3874687593264112  |1.1937133532954E7    |4734243.284902491   |
# |Fartcoin      |dex-aggregator       |2          |0.8687503458957715  |4343675.218889       |1722692.9044609398  |
# |Fartcoin      |lending-decentralized|1          |0.20970693838459328 |2097032.446188       |415839.4370466342   |
# |Jupiter       |dex-aggregator       |29         |68.74787873595494   |1.6591968476594996E8 |1.1356601792970421E9|
# |Jupiter       |NULL                 |43         |10.027839084510754  |1.6322080305046977E7 |1.6565191162358528E8|
# |Jupiter       |cex                  |26         |6.52569772661523    |1.7566701222132806E7 |1.0779932685210598E8|
# |Jupiter       |lending-decentralized|1          |0.14262703439857477 |9982480.29797        |2356084.9648874756  |
# |Jupiter       |dex                  |1          |0.059267420009952665|4148132.610733       |979050.5550504242   |
# |Pudgy Penguins|nft                  |6          |40.625093678841175  |5.396344969099751E9  |3.28699574512219E8  |
# |Pudgy Penguins|cex                  |52         |28.83343831400432   |4.4192611880291736E8 |2.332927274078812E8 |
# |Pudgy Penguins|NULL                 |38         |6.539331491941609   |1.371533236269085E8  |5.291004362939045E7 |
# |Pudgy Penguins|blockchain-infra     |1          |3.7346187328946923  |2.976479193389542E9  |3.021697865295516E7 |
# |Pudgy Penguins|dex                  |2          |0.5396216435669196  |2.15038362582017E8   |4366104.50772726    |
# |Pudgy Penguins|meme                 |1          |0.10748810738763026 |8.5667678030448E7    |869691.4139508657   |
# |SHARPEI       |dex                  |1          |97.97932137203135   |8.81723819517521E8   |436691.35609244264  |
# |SHARPEI       |NULL                 |94         |1.518388533706711   |145362.77597822333   |6767.419273521064   |
# |SHARPEI       |individual           |1          |0.07317151457193403 |658476.364245        |326.12358891962117  |
# |SHARPEI       |dex-aggregator       |4          |0.04681554805954065 |105324.223698        |208.65571308363383  |
# |Samoyed Coin  |cex                  |13         |27.558038324631116  |1.0062740580933443E8 |1014200.4788489453  |
# |Samoyed Coin  |NULL                 |76         |16.430487889126734  |1.0262382473274024E7 |604680.5105855512   |
# |Samoyed Coin  |dex                  |7          |4.3812894898908645  |2.9710861095413912E7 |161241.73449064413  |
# |Samoyed Coin  |lending-decentralized|1          |0.12284696117872429 |5831439.135892363    |4521.05644766599    |
# |Samoyed Coin  |dex-aggregator       |2          |0.09332379629449221 |2215000.0            |3434.5347           |
# |Samoyed Coin  |yield                |1          |0.08542073614636687 |4054848.561178158    |3143.683540995814   |
# |USD Coin      |cex                  |10         |1.5294609484136392  |1.1325391455195232E8 |1.1325391455195231E9|
# |USD Coin      |stablecoin           |4          |1.4363832275251256  |2.6590417931676525E8 |1.063616717267061E9 |
# |USD Coin      |NULL                 |61         |1.3860813234716745  |1.6825721885371182E7 |1.026369035007642E9 |
# |USD Coin      |meme                 |5          |0.7341272807967831  |1.0872168840381558E8 |5.436084420190779E8 |
# |USD Coin      |dex-aggregator       |3          |0.4858970164935598  |1.19932754181764E8   |3.59798262545292E8  |
# |USD Coin      |dex                  |8          |0.3845720888620881  |3.5596115200119495E7 |2.8476892160095596E8|
# |USD Coin      |derivatives          |2          |0.13721943368699605 |5.08042981867995E7   |1.01608596373599E8  |
# |USD Coin      |lending-decentralized|3          |0.1252997658722222  |3.092743011231267E7  |9.278229033693801E7 |
# |USD Coin      |fund                 |2          |0.03181325666890679 |1.17785807350515E7   |2.3557161470103E7   |
# |USD Coin      |misc                 |1          |0.028512422003276063|2.1112950994777E7    |2.1112950994777E7   |
# |USD Coin      |custodian            |1          |0.014207297250241004|1.052025571795E7     |1.052025571795E7    |
# |Wrapped Solana|dex                  |72         |16.032599354700018  |28719.095032334368   |2.6045691913964424E8|
# |Wrapped Solana|dex-aggregator       |2          |14.284383575453461  |921150.9731523404    |2.320563531565376E8 |
# |Wrapped Solana|lending-decentralized|8          |8.851919546289796   |142707.49348860545   |1.43803487038598E8  |
# |Wrapped Solana|bridge               |2          |4.2734114099506     |275577.665508842     |6.942352549498747E7 |
# |Wrapped Solana|NULL                 |9          |1.515398792613693   |21716.19509681022    |2.461834740954794E7 |
# |Wrapped Solana|derivatives          |2          |0.49630198789411895 |32004.815378363      |8062653.090117208   |
# |Wrapped Solana|fund                 |2          |0.2757430971114956  |17781.7279200465     |4479572.897618114   |
# |Wrapped Solana|meme                 |3          |0.25160545940936496 |10816.782890263      |4087445.9185725823  |
# +--------------+---------------------+-----------+--------------------+---------------------+--------------------+
#
#
# ================================================================================
# TOP 20 HOLDERS
# ================================================================================
# +--------------+--------------------------------------------+------------------------------+---------------------+-----------------------------------+-------------+-------------------+--------------+
# |token_name    |address                                     |entity_name                   |entity_type          |label_name                         |pct_of_supply|balance            |usd_value     |
# +--------------+--------------------------------------------+------------------------------+---------------------+-----------------------------------+-------------+-------------------+--------------+
# |Bonk          |9WzDXwBbmkg8ZTbNMqUxvQRAyrZzDsGYdLVL9zYtAWWM|Binance                       |cex                  |Cold Wallet                        |7.47         |6.5717499823234E12 |5.684563735E7 |
# |Bonk          |AGkGWK1R669KDT4FCqgDgK7PgahGJPjD4J9xmVjuL9kn|Bonk                          |meme                 |BonkDAO                            |5.03         |4.42610445030568E12|3.82858035E7  |
# |Bonk          |8Tp9fFkZ2KcRBLYDTUNXo98Ez6ojGb6MZEPXfGDdeBzG|Robinhood                     |cex                  |Cold Wallet                        |4.9          |4.31204685929589E12|3.729920533E7 |
# |Bonk          |9AdEE8AAm1XgJrPEs4zkTPozr3o4U5iGbgvPwkNdLDJ3|Bonk                          |meme                 |Stake Pool                         |3.83         |3.37127119095779E12|2.91614958E7  |
# |Bonk          |7Lp4JBapgNhXoxpJtR2twufh7oaQyqngqJpy7HFJcn7h|Upbit                         |cex                  |Hot Wallet                         |3.79         |3.33437732007567E12|2.884236382E7 |
# |Bonk          |3u2UcfncaoephiuQemKBML4GHVQhppGt3saNSAzvnrM8|Bonk Holdings Inc (SafetyShot)|fund                 |Squads Vault "BONK Holdings Inc"   |2.57         |2.25988126433173E12|1.954797294E7 |
# |Bonk          |8Mm46CsqxiyAputDUp2cXHg41HE3BfynTeMBDwzrMZQH|Bithumb                       |cex                  |Hot Wallet                         |2.08         |1.83033752509521E12|1.583241959E7 |
# |Bonk          |GJ8HjXMqQ79WRvxeAMRMng4ZTaohPcF1MZmBf9tVPpXA|NULL                          |NULL                 |NULL                               |1.62         |1.42313073361706E12|1.231008085E7 |
# |Bonk          |3B7XAQrLoEMDEGvX8569F9GRb9PcXXocJmj5wvhhei9z|BtcTurk                       |cex                  |Cold Wallet                        |1.62         |1.42261759200099E12|1.230564217E7 |
# |Bonk          |4xLpwxgYuPwPvtQjE94RLS4WZ4aD8NJYYKr2AJk99Qdg|Robinhood                     |cex                  |Hot Wallet                         |1.61         |1.41801480985458E12|1.226582811E7 |
# |Bonk          |CJjCPXBnSt6wRoyi7wzcMj5NbWvmPtzxE2JpWDMTRxj4|NULL                          |NULL                 |NULL                               |1.49         |1.30806236969766E12|1.13147395E7  |
# |Bonk          |8ijfaFjefHTnE385P5UgdNBwt4R9ftv6PZLsN6FPFf7A|NULL                          |NULL                 |NULL                               |1.14         |1.0E12             |8650000.0     |
# |Bonk          |GBrURzmtWujJRTA3Bkvo7ZgWuZYLMMwPCwre7BejJXnK|Binance                       |cex                  |Cold Wallet                        |1.12         |9.8643434552555E11 |8532657.09    |
# |Bonk          |EZ41WcMH3FmyWGV9WQaDLo5uo4ysVNdeAm1ZoTybxjsJ|NULL                          |NULL                 |NULL                               |0.97         |8.5334577965851E11 |7381440.99    |
# |Bonk          |F18jTyiQivKmuy3zYsJRjMBPgHab4is16betYFEY67WF|NULL                          |NULL                 |NULL                               |0.92         |8.1296454634773E11 |7032143.33    |
# |Bonk          |26kcZkdjJc94PdhqiLiEaGiLCYgAVVUfpDaZyK4cqih3|marginfi                      |lending-decentralized|Bank Liquidity Vault Authority     |0.8          |7.050933522711E11  |6099057.5     |
# |Bonk          |5tzFkiKscXHK5ZXCGbXZxdw7gTjjD1mBwuoFbhUvuAi9|Binance                       |cex                  |Hot Wallet                         |0.75         |6.5644536849158E11 |5678252.44    |
# |Bonk          |GugU1tP7doLeTw9hQP51xRJyS8Da1fWxuiy2rVrnMD2m|Wormhole                      |bridge               |Custody Authority                  |0.72         |6.2946698407173E11 |5444889.41    |
# |Bonk          |Am8MAEorCMAKxphqjAz3Ff59NEwPm4W2eS3DQLi2B4hg|NULL                          |NULL                 |NULL                               |0.69         |6.045610320156E11  |5229452.93    |
# |Bonk          |2Ejnns2Fd5gsZdFJbnkZmQEwbrgoiMc2ikKcS2z2Ps3e|NULL                          |NULL                 |NULL                               |0.68         |6.0121609533176E11 |5200519.22    |
# |Fartcoin      |9SLPTL41SPsYkgdsMzdfJsxymEANKr5bYoBsQzJyKpKS|Hyperunit                     |blockchain-infra     |Hot Wallet                         |7.14         |7.135429655E7      |1.414948565E7 |
# |Fartcoin      |u6PJ8DtQuPFnfmwHbGFULQ4u4EgjDiyYKjVEsynXq2w |Gate                          |cex                  |Hot Wallet                         |6.01         |6.007011537E7      |1.191184381E7 |
# |Fartcoin      |35hxjkNKK8svYuGkMYNv43UCGAEa1Z1k6vkZzZaoR341|NULL                          |NULL                 |NULL                               |3.93         |3.92529797E7       |7783826.62    |
# |Fartcoin      |7TWnq4WeYcwQWBCwKeEX2Q9xqVtthPGkB7adNvueuVuh|Bitget                        |cex                  |Cold Wallet                        |3.59         |3.586228155E7      |7111454.57    |
# |Fartcoin      |E2RvJg2myWpKcbkhBuF81gfhYr6KvmNcDbSmr5qnatYy|Kraken                        |cex                  |Cold Wallet                        |2.88         |2.876193796E7      |5703463.54    |
# |Fartcoin      |5Q544fKrFoe6tsEbD7S8EmxGTJYAKtTVhAW5Q5pge4j1|Raydium                       |dex                  |Authority V4                       |2.16         |2.164423002E7      |4292029.17    |
# |Fartcoin      |6LY1JzAFVZsP2a2xKrtU6znQMQ5h4i7tocWdgrkZzkzF|Kraken                        |cex                  |Hot Wallet                         |2.06         |2.058351174E7      |4081689.79    |
# |Fartcoin      |ASTyfSima4LLAdDgoFGkgqoKowG1LZFDr9fAQrg7iaJZ|MEXC                          |cex                  |Hot Wallet                         |1.73         |1.729373433E7      |3429330.22    |
# |Fartcoin      |EFE3j1pcSP1paUzA86zW7989ZjsFP2J7ginyUqo4ewqR|Kraken                        |cex                  |Cold Wallet                        |1.68         |1.677778698E7      |3327018.38    |
# |Fartcoin      |4QXXp184iMKjL1ZTLrGtjMFvR2n2YhpUS1WypmzGaYB3|Indodax                       |cex                  |Hot Wallet                         |1.66         |1.664838708E7      |3301358.51    |
# |Fartcoin      |6BhBoBB47wSGjK5uzcGWNcTf2oNRPQNuv6GVdkNyj9PB|KuCoin                        |cex                  |Cold Wallet                        |1.22         |1.21532E7          |2409967.41    |
# |Fartcoin      |9ZPsRWGkukYeWg2Z7eZ8NaTBZ1DSuBUVzLcGQWZgE4Y4|NULL                          |NULL                 |NULL                               |1.06         |1.064595314E7      |2111081.86    |
# |Fartcoin      |38ESLHdJkqNvMbJmbgsHJGXjJPpsL4TkvSUgXegYgvpr|NULL                          |NULL                 |"esh69" on Pump.fun                |1.0          |1.000104732E7      |1983197.68    |
# |Fartcoin      |4QuB7hY3H512CLG1orbVrA7HTeXbBYCPxBpNfQ6gs5ru|NULL                          |NULL                 |Indodax Deposit                    |1.0          |9999995.13         |1982989.03    |
# |Fartcoin      |2m2fV6UHDqqMPHrFrKdtn53teChJbKUEnK9SBgF37xTj|NULL                          |NULL                 |NULL                               |0.9          |9038660.14         |1792357.27    |
# |Fartcoin      |8qfwnup4rqs1wGrc79yPakQk8oyavqy1nx8eSgEqSU1i|NULL                          |NULL                 |NULL                               |0.9          |9038660.14         |1792357.27    |
# |Fartcoin      |9BUK6Q14RHiQFQy3c3UeSEjzBryV2D5GyYeMuPesG4ph|NULL                          |NULL                 |NULL                               |0.9          |9038660.14         |1792357.27    |
# |Fartcoin      |BUucuh9DmUYq7E3fa2zn3FsWhYtHWUfUnfxaoo8BEczi|NULL                          |NULL                 |NULL                               |0.87         |8703346.33         |1725864.87    |
# |Fartcoin      |tLoQPvd5rdZQgmzaZmGMC1j7xQfPK8FGcaoarqP3yyV |NULL                          |NULL                 |NULL                               |0.86         |8575918.48         |1700596.06    |
# |Fartcoin      |79sJvLQ3QrL88Uc9jgV3iTT5Ft19xtMbjmAkhgoKh38W|NULL                          |NULL                 |Fireblocks Custody                 |0.83         |8280323.09         |1641979.79    |
# |Jupiter       |61aq585V8cR2sZBeawJFt2NPqmN7zDi1sws4KLs5xHXV|Jupiter                       |dex-aggregator       |Team Cold Wallet                   |25.71        |1.79936666824E9    |4.2469011977E8|
# |Jupiter       |EXJHiMkj6NRFDfhWBMKccHNwdSpCT7tdvQeRf87yHm6T|Jupiter                       |dex-aggregator       |Community Cold Wallet              |24.29        |1.7E9              |4.012374E8    |
# |Jupiter       |FVhQ3QHvXudWSdGix2sdcG47YmrmUxRhf3KCBmiKfekf|Jupiter                       |dex-aggregator       |Community Hot Wallet               |5.31         |3.7149292374E8     |8.768050285E7 |
# |Jupiter       |Any5gL74oUQy9Psb3goym9STaYMau4CMrTkryS37T7iz|Jupiter                       |dex-aggregator       |Squads Vault "Team Admin"          |4.56         |3.1943322682E8     |7.539326906E7 |
# |Jupiter       |BmEyv8gu9d4aDm5n96nyC3K328cn5UAR5ddVK1CSF1j2|NULL                          |NULL                 |NULL                               |3.21         |2.2462614088E8     |5.301671102E7 |
# |Jupiter       |9WzDXwBbmkg8ZTbNMqUxvQRAyrZzDsGYdLVL9zYtAWWM|Binance                       |cex                  |Cold Wallet                        |2.23         |1.563044312E8      |3.689128446E7 |
# |Jupiter       |6tZT9AUcQn4iHMH79YZEXSy55kDLQ4VbA3PMtfLVNsFX|Jupiter                       |dex-aggregator       |Squads Vault "Team"                |2.08         |1.4543889417E8     |3.432677868E7 |
# |Jupiter       |CbU4oSFCk8SVgW23NLvb5BwctvWcZZHfxRD6HudP8gAo|Jupiter                       |dex-aggregator       |Team Hot Wallet                    |1.81         |1.2637693304E8     |2.982773649E7 |
# |Jupiter       |CPZmKkAhD2wv1Z21EUZvdH8ZeSD13geAnSfyVBwcW8XK|Jupiter                       |dex-aggregator       |Squads Vault "Jupiter DAO Multisig"|1.48         |1.0386951685E8     |2.451549111E7 |
# |Jupiter       |6wsjaQTidXNqmPDw4st2yMtFmTk7yyBEox5SydFQeJe7|NULL                          |NULL                 |Escrow                             |1.35         |9.441476737E7      |2.228396222E7 |
# |Jupiter       |27b4PRN7K37rpTywq65t29rjuNfQkYpxZUjkbtHc5VvZ|Upbit                         |cex                  |Hot Wallet                         |1.11         |7.788550398E7      |1.838269242E7 |
# |Jupiter       |BN5sEedysJxragPcFoR5UDXSiA7oZLe2FPbo7tZ2MZCG|Jupiter                       |dex-aggregator       |Escrow                             |0.53         |3.702420564E7      |8738527.06    |
# |Jupiter       |HmU2GUjRjWxFJ7PLZWC4ULKco5qN4NCUhx6hsRo6WgG3|NULL                          |NULL                 |Escrow                             |0.45         |3.147158928E7      |7427987.45    |
# |Jupiter       |HZVW75BkNM6JyFerRgrtkpAzDSoZj6Z8HSaf9RPWvydy|NULL                          |NULL                 |Escrow                             |0.45         |3.147158887E7      |7427987.35    |
# |Jupiter       |5JA6jjjTKSEMDUKRcNgVmVtn7QcpWWkL7svTNVjgksEq|NULL                          |NULL                 |Escrow                             |0.45         |3.147158887E7      |7427987.35    |
# |Jupiter       |9K1SJYStwyA7kV2j5gZvqhtSujEhRr5WvES6JRgMyYUY|Jupiter                       |dex-aggregator       |Escrow                             |0.39         |2.75229255E7       |6496015.92    |
# |Jupiter       |7s1da8DduuBFqGra5bJBjpnvL5E9mGzCuMk1Qkh4or2Z|Jupiter                       |dex-aggregator       |Supply Vault Owner                 |0.39         |2.72448982E7       |6430395.36    |
# |Jupiter       |8Mm46CsqxiyAputDUp2cXHg41HE3BfynTeMBDwzrMZQH|Bithumb                       |cex                  |Hot Wallet                         |0.38         |2.657908375E7      |6273248.51    |
# |Jupiter       |Ew6iUFb1dwu2fy1apprCJBa27mnpV6rZTe9XYeDnfQZc|NULL                          |NULL                 |NULL                               |0.37         |2.617021501E7      |6176746.49    |
# |Jupiter       |DxqXs26CLNiFd7Dm2WG7J28RPmbrzRXYfM5tfb84dkkx|Jupiter                       |dex-aggregator       |Escrow                             |0.37         |2.588093774E7      |6108470.69    |
# |Pudgy Penguins|GcEXZEUhbK4KyFV7B7q28Zh7PKzGsC3oqgjvGRLaZJZu|Pudgy Penguins                |nft                  |Fireblocks Custody                 |15.69        |1.250731899839E10  |1.2697330189E8|
# |Pudgy Penguins|GziA3ZgkmnUcK9vuscnDpzLTcpHTSnmyQ6JwPKP5oSkR|Pudgy Penguins                |nft                  |Deployer                           |9.04         |7.20408352682E9    |7.313527964E7 |
# |Pudgy Penguins|9WzDXwBbmkg8ZTbNMqUxvQRAyrZzDsGYdLVL9zYtAWWM|Binance                       |cex                  |Cold Wallet                        |6.45         |5.1396126124E9     |5.217693607E7 |
# |Pudgy Penguins|XqDwNVzNKQoMrofeDz8vMUdCGs5zqrjhbq8K1c21gCm |Pudgy Penguins                |nft                  |Fireblocks Custody                 |5.86         |4.66666728839E9    |4.737563298E7 |
# |Pudgy Penguins|F7hiM7VLhxLTsWRmhc1B6KS5DckAxaShug2qjVpndwSe|Pudgy Penguins                |nft                  |Fireblocks Custody                 |4.6          |3.666666667E9      |3.722370667E7 |
# |Pudgy Penguins|qMNo1RFo11J9ZLGuq7dVmWAssuCZaNsSamk8g2q4UZA |Abstract                      |blockchain-infra     |Bridge                             |3.73         |2.97647919339E9    |3.021697865E7 |
# |Pudgy Penguins|8Tp9fFkZ2KcRBLYDTUNXo98Ez6ojGb6MZEPXfGDdeBzG|Robinhood                     |cex                  |Cold Wallet                        |3.65         |2.91226765281E9    |2.956510823E7 |
# |Pudgy Penguins|3XsT6m5nY62funuJu4xUXyjUeuU5g9DjutgBY6binrrC|Pudgy Penguins                |nft                  |Fireblocks Custody                 |3.35         |2.666666667E9      |2.707178667E7 |
# |Pudgy Penguins|5PLU3MB93miiNvd1dcY6VkWSzjeGBQpssqbbBJDALrkm|Upbit                         |cex                  |Hot Wallet                         |3.32         |2.64957629323E9    |2.689828656E7 |
# |Pudgy Penguins|8Mm46CsqxiyAputDUp2cXHg41HE3BfynTeMBDwzrMZQH|Bithumb                       |cex                  |Hot Wallet                         |2.77         |2.20767342195E9    |2.241212397E7 |
# |Pudgy Penguins|VYXUZbPGzTnkUuWXyPf5H4Q6bLv2xBrSQkoUuNCXmWN |Pudgy Penguins                |nft                  |Fireblocks Custody                 |2.09         |1.666666667E9      |1.691986667E7 |
# |Pudgy Penguins|5tzFkiKscXHK5ZXCGbXZxdw7gTjjD1mBwuoFbhUvuAi9|Binance                       |cex                  |Hot Wallet                         |0.89         |7.1088973283E8     |7216895.7     |
# |Pudgy Penguins|Gem2VAypSg7Ai7vjDKPTtqFahpoQWkfgVkyzx3rPoTka|Bybit                         |cex                  |Hot Wallet                         |0.79         |6.2897687068E8     |6385322.87    |
# |Pudgy Penguins|CBEADkb8TZAXHjVE3zwad4L995GZE7rJcacJ7asebkVG|OKX                           |cex                  |Cold Wallet                        |0.74         |5.8781902861E8     |5967491.75    |
# |Pudgy Penguins|4xLpwxgYuPwPvtQjE94RLS4WZ4aD8NJYYKr2AJk99Qdg|Robinhood                     |cex                  |Hot Wallet                         |0.73         |5.7810731858E8     |5868899.25    |
# |Pudgy Penguins|4HMHt1WjhFT3cH24U8zkrzyD3ZTvfFbGG4WpfVbk9cvz|NULL                          |NULL                 |Fireblocks Custody                 |0.56         |4.44444444E8       |4511964.44    |
# |Pudgy Penguins|E2RvJg2myWpKcbkhBuF81gfhYr6KvmNcDbSmr5qnatYy|Kraken                        |cex                  |Cold Wallet                        |0.55         |4.3675079012E8     |4433859.08    |
# |Pudgy Penguins|3B7XAQrLoEMDEGvX8569F9GRb9PcXXocJmj5wvhhei9z|BtcTurk                       |cex                  |Cold Wallet                        |0.45         |3.5799433166E8     |3634329.82    |
# |Pudgy Penguins|CMivUnnbDHxLq9ChV1bSuiQE5ycZf6JVvFFDePMHhHYK|Bybit                         |cex                  |Cold Wallet                        |0.44         |3.50000009E8       |3553172.09    |
# |Pudgy Penguins|8RDXBPFGwUw9nKEjT8kqwmcoeZeNics4UtZvekZsRXvQ|NULL                          |NULL                 |NULL                               |0.44         |3.4751146168E8     |3527908.56    |
# |SHARPEI       |5Q544fKrFoe6tsEbD7S8EmxGTJYAKtTVhAW5Q5pge4j1|Raydium                       |dex                  |Authority V4                       |97.98        |8.8172381952E8     |436691.36     |
# |SHARPEI       |6tFZfmfeeETWKMyE5RyQKLqwLHcgXmiu1uU15iMWob6z|NULL                          |NULL                 |NULL                               |0.2          |1801244.3          |892.1         |
# |SHARPEI       |CHj3vHyMhF6DF3VkwhzgK833o7uvsN7CrPVyUdmbFo5E|NULL                          |NULL                 |NULL                               |0.11         |1003709.48         |497.11        |
# |SHARPEI       |2JG298cCP8JZYyXojKRRhGFauEvKEF3LaENoUz7icvtU|NULL                          |NULL                 |NULL                               |0.11         |1000000.0          |495.27        |
# |SHARPEI       |EccxYg7rViwYfn9EMoNu7sUaV82QGyFt6ewiQaH1GYjv|NULL                          |NULL                 |NULL                               |0.08         |758592.96          |375.71        |
# |SHARPEI       |6vswEQdG8kX5DSn5waivDwDvpRSvPkf8h74TbpNSasmu|NULL                          |NULL                 |"6vswEQ" on Pump.fun               |0.08         |742981.14          |367.98        |
# |SHARPEI       |DFPhzedeyLUKVDGsDiNW7uJZGGAxmp5ToytrqpGrAdmC|NULL                          |NULL                 |NULL                               |0.08         |683760.16          |338.65        |
# |SHARPEI       |HUpPyLU8KWisCAr3mzWy2FKT6uuxQ2qGgJQxyTpDoes5|@0xSunNFT                     |individual           |0xsun.sol                          |0.07         |658476.36          |326.12        |
# |SHARPEI       |3oHe5SyJhqAX4VBw4Lgjw3XfdzU8wpqDAAwRktV24wZZ|NULL                          |NULL                 |NULL                               |0.06         |506903.74          |251.05        |
# |SHARPEI       |6Gt4PF799FMurfkmCcts6mg786hWZeBAVQJCvQtkrrzn|NULL                          |NULL                 |NULL                               |0.05         |413627.75          |204.86        |
# |SHARPEI       |DNfuF1L62WWyW3pNakVkyGGFzVVhj4Yr52jSmdTyeBHm|NULL                          |NULL                 |NULL                               |0.04         |380876.41          |188.64        |
# |SHARPEI       |FyMLmRNbznAoTKkaDbmTqPx82ymo2akUoT4njansaGee|NULL                          |NULL                 |"DK0212" on Pump.fun               |0.04         |361641.76          |179.11        |
# |SHARPEI       |ByTtsfRVqVPe51t5kGhnYqTwTCRaubZZDsGfwShvtHDt|NULL                          |NULL                 |NULL                               |0.03         |254829.52          |126.21        |
# |SHARPEI       |9hHLLZommh57mQJmaTEjBuHbe8cJwgEnmdXSqF1jNwXo|NULL                          |NULL                 |NULL                               |0.03         |253275.35          |125.44        |
# |SHARPEI       |pVsyxxyUwQ8v6PWyEnU7fJdrpEo1RRnBjtrpZ8BBBwD |NULL                          |NULL                 |NULL                               |0.03         |240146.56          |118.94        |
# |SHARPEI       |hZ9qoEqnn9Adf427UqUVT8YKYkAeYfNvz2fvfx9a52w |NULL                          |NULL                 |NULL                               |0.02         |219301.44          |108.61        |
# |SHARPEI       |45ruCyfdRkWpRNGEqWzjCiXRHkZs8WXCLQ67Pnpye7Hp|Jupiter                       |dex-aggregator       |Partner Referral Fee Vault         |0.02         |212702.47          |105.35        |
# |SHARPEI       |HfoXWebGY6aEFvob6m8oE3sHvqWH1D7X2GfuWECLHmmQ|NULL                          |NULL                 |NULL                               |0.02         |203711.85          |100.89        |
# |SHARPEI       |72jNC2ujhY19wcr3zskiQM8VXXdLjTdwp6vQejGRtT58|NULL                          |NULL                 |NULL                               |0.02         |195106.3           |96.63         |
# |SHARPEI       |CmHKQf4MeDdCSbVJkcqhS5EizTrsFAp4fUNjpe9tA6Qt|NULL                          |NULL                 |NULL                               |0.02         |157136.53          |77.83         |
# |Samoyed Coin  |u6PJ8DtQuPFnfmwHbGFULQ4u4EgjDiyYKjVEsynXq2w |Gate                          |cex                  |Hot Wallet                         |8.35         |3.9629428098E8     |307242.99     |
# |Samoyed Coin  |EFE3j1pcSP1paUzA86zW7989ZjsFP2J7ginyUqo4ewqR|Kraken                        |cex                  |Cold Wallet                        |4.2          |1.992368605E8      |154466.35     |
# |Samoyed Coin  |4TYF8iW8bXET9C8aFgJoiUHhNtpBg5bqRsxSptCExvz7|NULL                          |NULL                 |NULL                               |3.46         |1.6402781341E8     |127169.12     |
# |Samoyed Coin  |6LY1JzAFVZsP2a2xKrtU6znQMQ5h4i7tocWdgrkZzkzF|Kraken                        |cex                  |Hot Wallet                         |3.1          |1.4696002051E8     |113936.63     |
# |Samoyed Coin  |C68a6RCGLiPskbPYtAcsCjhG8tfTWYcoB4JjCrXFdqyo|OKX                           |cex                  |Hot Wallet                         |3.03         |1.4398106216E8     |111627.08     |
# |Samoyed Coin  |ASTyfSima4LLAdDgoFGkgqoKowG1LZFDr9fAQrg7iaJZ|MEXC                          |cex                  |Hot Wallet                         |2.94         |1.393558392E8      |108041.19     |
# |Samoyed Coin  |J9pm7akNvEz2VkBaLECk5J8hSj3tnrMrPDLHq9zcHDuN|NULL                          |NULL                 |Gemini Deposit                     |2.29         |1.0863445546E8     |84223.21      |
# |Samoyed Coin  |AB4rTE2JiKFhnfynUQCovbW75CUxT9LxcJX2SDTbY9gy|Orca                          |dex                  |Authority                          |1.89         |8.974417795E7      |69577.76      |
# |Samoyed Coin  |6xfPFKnwv48XvxpFf4athewqGFvSTKQcMmfzYapgZ2sG|BingX                         |cex                  |Cold Wallet                        |1.6          |7.582309373E7      |58784.89      |
# |Samoyed Coin  |2Ejnns2Fd5gsZdFJbnkZmQEwbrgoiMc2ikKcS2z2Ps3e|NULL                          |NULL                 |NULL                               |1.47         |6.975861126E7      |54083.15      |
# |Samoyed Coin  |A77HErqtfN1hLLpvZ9pCtu66FEtM8BveoaKbbMoZ4RiR|Bitget                        |cex                  |Hot Wallet                         |1.37         |6.494204589E7      |50348.92      |
# |Samoyed Coin  |5PAhQiYdLBd6SVdjzBQDxUAEFyDdF5ExNPQfcscnPRj5|MEXC                          |cex                  |Hot Wallet                         |1.09         |5.178901427E7      |40151.5       |
# |Samoyed Coin  |5Q544fKrFoe6tsEbD7S8EmxGTJYAKtTVhAW5Q5pge4j1|Raydium                       |dex                  |Authority V4                       |0.99         |4.694072647E7      |36392.68      |
# |Samoyed Coin  |ztXuoDC83evb4GGBjk18sWpeiQNaiGXKQ6DN9xyf77r |NULL                          |NULL                 |NULL                               |0.75         |3.57451522E7       |27712.86      |
# |Samoyed Coin  |679pdaM91fct45cM3nCvzBN57UGCFHe1CTSJwSRqjGwJ|Serum                         |dex                  |Vault Signer                       |0.7          |3.3171157E7        |25717.27      |
# |Samoyed Coin  |4UP7t9p3HEd9gfF9gFKkGa1ZvLXFS2naHgnxB4fwpLfS|OKX                           |cex                  |Hot Wallet                         |0.61         |2.88553811E7       |22371.29      |
# |Samoyed Coin  |HLEDVZvwnSrVDtns2v38dyEFxy313SViMWhZrZ4DkTJT|NULL                          |NULL                 |NULL                               |0.59         |2.801410375E7      |21719.05      |
# |Samoyed Coin  |BLzsW62YMD8FtxppKYPRXL3CDPWP2DWoyb7qvGkyd3rB|NULL                          |NULL                 |NULL                               |0.53         |2.501405233E7      |19393.14      |
# |Samoyed Coin  |BmFdpraQhkiDQE6SnfG5omcA1VwzqfXrwtNYBwWTymy6|KuCoin                        |cex                  |Hot Wallet                         |0.49         |2.342440982E7      |18160.71      |
# |Samoyed Coin  |8Czzjeh2igeE7gSsbuuXVZUmZZ42yZTCNUZoZcCGRKdr|NULL                          |NULL                 |NULL                               |0.42         |1.980668024E7      |15355.92      |
# |USD Coin      |7VHUFJHWu2CuExkJcJrzhQPJ2oygupTWkL2A2For4BmE|Circle                        |stablecoin           |NULL                               |1.14         |8.4418058683E8     |8.4418058683E8|
# |USD Coin      |5tzFkiKscXHK5ZXCGbXZxdw7gTjjD1mBwuoFbhUvuAi9|Binance                       |cex                  |Hot Wallet                         |0.82         |6.0923044954E8     |6.0923044954E8|
# |USD Coin      |AVzP2GeRmqGphJsMxWoqjpUifPpCret7LqWhD8NWQK49|Jupiter                       |dex-aggregator       |Perpetuals Vault Authority         |0.33         |2.4497252245E8     |2.4497252245E8|
# |USD Coin      |8Vkgsarud8mSc1gkzayGA7XhNQfq4wDJRxTWDgq8RaJD|Bullish.com                   |cex                  |Cold Wallet                        |0.28         |2.1000012201E8     |2.1000012201E8|
# |USD Coin      |9d9mb8kooFfaD3SctgZtkxQypkshx6ezhbKio89ixyy2|Meteora (Prev. Mercurial)     |dex                  |Market                             |0.23         |1.7343899506E8     |1.7343899506E8|
# |USD Coin      |HGRErGQVy9JyJ2JsSp2uj32DBXMYbSDAGixc482jAFxp|pump.fun                      |meme                 |Squads Vault "Token Cold SOL1"     |0.2          |1.5001079904E8     |1.5001079904E8|
# |USD Coin      |G9XbC9ggrBYogsZgKYf2pnTvPnJ9z5Zd6WG8BuyioTA9|pump.fun                      |meme                 |Squads Vault "Token Secure SOL1"   |0.2          |1.49999755E8       |1.49999755E8  |
# |USD Coin      |4jtZwKHXD7vToiiPyqwa9467FQc19Mcy62wSFHijZqqE|pump.fun                      |meme                 |Squads Vault "Coin 1 SOL3"         |0.18         |1.3526251925E8     |1.3526251925E8|
# |USD Coin      |DBD8hAwLDRQkTsu6EqviaYNGKPnsAMmQonxf7AH8ZcFY|Circle                        |stablecoin           |CCTP Token Minter                  |0.16         |1.2090880379E8     |1.2090880379E8|
# |USD Coin      |7s1da8DduuBFqGra5bJBjpnvL5E9mGzCuMk1Qkh4or2Z|Jupiter                       |dex-aggregator       |Supply Vault Owner                 |0.14         |1.0670987619E8     |1.0670987619E8|
# |USD Coin      |7aq6Jka4kHUnuvU6v14npvSCosurThVYf47zRPFMProZ|NULL                          |NULL                 |Coinbase Deposit                   |0.14         |1.0000000009E8     |1.0000000009E8|
# |USD Coin      |JCNCMFXo5M5qwUPg2Utu1u6YWp3MbygxqBsBeXXJfrw |Drift Protocol                |derivatives          |Vault                              |0.1          |7.598304942E7      |7.598304942E7 |
# |USD Coin      |41zCUJsKk6cMB94DDtm99qWmyMZfp4GkAhhuz4xTwePu|Circle                        |stablecoin           |Treasury                           |0.1          |7.291887775E7      |7.291887775E7 |
# |USD Coin      |3csuXZKah5rgpb8RiwX9XfjrMxcp3u1K9mBdCwL51spj|pump.fun                      |meme                 |Squads Vault "New Cold SOL1"       |0.1          |7.271711284E7      |7.271711284E7 |
# |USD Coin      |6FEVkH17P9y8Q9aCkDdPcMDjvj7SVxrTETaYEm8f51Jy|Crypto.com                    |cex                  |Hot Wallet                         |0.09         |6.909970022E7      |6.909970022E7 |
# |USD Coin      |Bc5bth4Mn2n8DX1etZwvnq3uDEGg479s2D24TCEsnXHf|Bullish.com                   |cex                  |Hot Wallet                         |0.09         |6.69035407E7       |6.69035407E7  |
# |USD Coin      |9DrvZvyWh1HuAoZxvYWMvkf2XCzryCpGgHqrMjyDWpmo|Kamino Finance                |lending-decentralized|Reserve                            |0.08         |6.07280787E7       |6.07280787E7  |
# |USD Coin      |3Ln6KEgLoMR2xFHfqtYazP7CxFQPDtUVVtwCVsLKVfmV|BingX                         |cex                  |Cold Wallet                        |0.08         |5.794876637E7      |5.794876637E7 |
# |USD Coin      |HPvAiC7pJdE136t7YrNTUJ5on5NNqhcUr4onLiJYteUe|NULL                          |NULL                 |NULL                               |0.06         |4.730504873E7      |4.730504873E7 |
# |USD Coin      |6LY1JzAFVZsP2a2xKrtU6znQMQ5h4i7tocWdgrkZzkzF|Kraken                        |cex                  |Hot Wallet                         |0.06         |4.730415036E7      |4.730415036E7 |
# |Wrapped Solana|AVzP2GeRmqGphJsMxWoqjpUifPpCret7LqWhD8NWQK49|Jupiter                       |dex-aggregator       |Perpetuals Vault Authority         |10.11        |1303685.59         |1.6421223734E8|
# |Wrapped Solana|9DrvZvyWh1HuAoZxvYWMvkf2XCzryCpGgHqrMjyDWpmo|Kamino Finance                |lending-decentralized|Reserve                            |5.78         |745561.22          |9.391089184E7 |
# |Wrapped Solana|GugU1tP7doLeTw9hQP51xRJyS8Da1fWxuiy2rVrnMD2m|Wormhole                      |bridge               |Custody Authority                  |4.18         |539202.41          |6.791793502E7 |
# |Wrapped Solana|7s1da8DduuBFqGra5bJBjpnvL5E9mGzCuMk1Qkh4or2Z|Jupiter                       |dex-aggregator       |Supply Vault Owner                 |4.18         |538616.35          |6.784411582E7 |
# |Wrapped Solana|Czfq3xZZDmsdGdUyrNLtRhGc47cXcZtLG4crryfu44zE|Orca                          |dex                  |Market                             |2.23         |287616.42          |3.622816481E7 |
# |Wrapped Solana|DdZR6zRFiUt4S5mg7AV1uKB2z1f1WzcNYCaTEEWPAuby|Save (prev. Solend)           |lending-decentralized|Lending Authority                  |1.67         |215484.81          |2.714246624E7 |
# |Wrapped Solana|3ucNos4NbumPLZNWztqGHNFFgkHeRMBQAVemeeomsUxv|Raydium                       |dex                  |Market                             |0.76         |98433.58           |1.239869344E7 |
# |Wrapped Solana|DD3AeAssFvjqTvRTrRAtpfjkBF8FpVKnFuwnMLN9haXD|marginfi                      |lending-decentralized|Bank Liquidity Vault Authority     |0.75         |96089.27           |1.210340469E7 |
# |Wrapped Solana|Hp53XEtt4S8SvPCXarsLSdGfZBuUr5mMmZmX2DRNXQKp|Orca                          |dex                  |Market                             |0.66         |85221.74           |1.073453036E7 |
# |Wrapped Solana|5Q544fKrFoe6tsEbD7S8EmxGTJYAKtTVhAW5Q5pge4j1|Raydium                       |dex                  |Authority V4                       |0.66         |84728.91           |1.067245304E7 |
# |Wrapped Solana|5Q544fKrFoe6tsEbD7S8EmxGTJYAKtTVhAW5Q5pge4j1|Raydium                       |dex                  |Authority V4                       |0.65         |83774.43           |1.05522275E7  |
# |Wrapped Solana|CeaZcxBNLpJWtxzt58qQmfMBtJY8pQLvursXTJYGQpbN|Orca                          |dex                  |Market                             |0.48         |61993.97           |7808760.35    |
# |Wrapped Solana|5Q544fKrFoe6tsEbD7S8EmxGTJYAKtTVhAW5Q5pge4j1|Raydium                       |dex                  |Authority V4                       |0.47         |61153.61           |7702908.93    |
# |Wrapped Solana|5Q544fKrFoe6tsEbD7S8EmxGTJYAKtTVhAW5Q5pge4j1|Raydium                       |dex                  |Authority V4                       |0.43         |55957.72           |7048434.12    |
# |Wrapped Solana|FERjPVNEa7Udq8CEv68h6tPL46Tq7ieE49HrE2wea3XT|Meteora (Prev. Mercurial)     |dex                  |Vault Authority                    |0.42         |54574.14           |6874158.79    |
# |Wrapped Solana|2Sj4MZvmLhud4uRmGHJvDxq612nmF4JJsU1R4ZjNNGMS|Saber                         |dex                  |Pool Authority                     |0.42         |54506.1            |6865588.35    |
# |Wrapped Solana|7VuKeevbvbQQcxz6N4SNLmuq6PYy4AcGQRDssoqo4t65|Fusion AMM                    |dex                  |NULL                               |0.41         |52597.68           |6625203.53    |
# |Wrapped Solana|JCNCMFXo5M5qwUPg2Utu1u6YWp3MbygxqBsBeXXJfrw |Drift Protocol                |derivatives          |Vault                              |0.39         |50169.35           |6319330.76    |
# |Wrapped Solana|AQAGYQsdU853WAKhXM79CgNdoyhrRwXvYHX6qrDyC1FS|Raydium                       |dex                  |Market                             |0.36         |45995.15           |5793549.09    |
# |Wrapped Solana|BGm1tav58oGcsQJehL9WXBFXF7D27vZsKefj4xJKD5Y |Meteora (Prev. Mercurial)     |dex                  |Market                             |0.34         |44339.06           |5584947.56    |
# +--------------+--------------------------------------------+------------------------------+---------------------+-----------------------------------+-------------+-------------------+--------------+

# %% [markdown]
# # Summary (2):
# * Concentration risk matters: Highly concentrated holdings increase vulnerability to manipulations, sudden dumps, or rug pulls.
# * Entity type distinction: CEX-controlled holdings are less risky operationally but may signal centralization; unknown wallets can be red flags.
# * Weighted scoring: The weighting reflects the relative importance of each factor in assessing systemic risk:
# * Top 10 concentration (largest group control) – 45%
# * Unknown entities (opaque control) – 30%
# * Largest single holder (whale) – 25%
# * Dynamic and comparative: Scores are normalized relative to all analyzed tokens to make risk assessment meaningful across different projects.
